# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('data/input.tsv', sep='\t', index_col='ID')
del dataset['days_to_disease_progression']

dataset = dataset.loc[~dataset['therapy_first_line_class'].isnull()]

therapy_class = dataset['therapy_first_line_class']
therapy = dataset['therapy_first_line']
del dataset['therapy_first_line']

del dataset['best_response_first_line']
del dataset['therapy_first_line_class']
del dataset['days_to_disease_progression_class']


dataset = dataset[~dataset['best_response_first_line_class'].isnull()]

dataset.iloc[:10, :10]
# Out:
#           best_response_first_line_class           lgh           lgl  \
# ID
# MMRF1011                             0.0  Not Recorded  Not Recorded
# MMRF1013                             1.0       Unknown       Unknown
# MMRF1016                             0.0           IgG        Lambda
# MMRF1017                             0.0           IgG        Lambda
# MMRF1018                             0.0           IgA         Kappa
# MMRF1029                             0.0       Unknown         Kappa
# MMRF1030                             1.0           IgG         Kappa
# MMRF1031                             0.0           IgA       Unknown
# MMRF1032                             0.0           IgG        Lambda
# MMRF1033                             0.0           IgG         Kappa
#
#           percent_aneuploid  percent_plama_cells_bone_marrow  \
# ID
# MMRF1011                0.0                              0.9
# MMRF1013                0.0                              1.3
# MMRF1016                0.0                              2.0
# MMRF1017                6.9                              2.1
# MMRF1018                0.0                              2.1
# MMRF1029                0.0                              8.4
# MMRF1030               15.4                              9.6
# MMRF1031               18.3                             10.1
# MMRF1032               20.7                             11.1
# MMRF1033               18.5                             12.0
#
#           percent_plama_cells_peripherical_blood  creatinine  iss  \
# ID
# MMRF1011                                     0.0     123.760    3
# MMRF1013                                     0.2     186.524    3
# MMRF1016                                     0.0      86.632    1
# MMRF1017                                     0.0      79.560    1
# MMRF1018                                     0.0     133.484    3
# MMRF1029                                     0.0     106.080    1
# MMRF1030                                     0.0      55.692    1
# MMRF1031                                     0.0      81.328    1
# MMRF1032                                     0.0      70.720    2
# MMRF1033                                     0.0      79.560    1
#
#           absolute_neutrophil  platelet
# ID
# MMRF1011                 8.28     170.0
# MMRF1013                 4.33     245.0
# MMRF1016                 5.80     177.0
# MMRF1017                 3.69     191.0
# MMRF1018                 5.60     271.0
# MMRF1029                 2.60     219.0
# MMRF1030                 2.50     215.0
# MMRF1031                10.29     385.0
# MMRF1032                 1.30     166.0
# MMRF1033                 3.99     307.0

# %%
len(therapy_class)
# Out:
# 711

# %%
def generate_metric(t, auc, tn, fp, fn, tp, title='THERAPY'):
    
    sensitivity = (tp / float(tp + fn)) if tp + fn > 0 else 1

    precision =  (tp / float(tp + fp)) if tp + fp > 0 else 1

    specificity = (tn / float(tn + fp)) if tn + fp > 0 else 1

    ks = abs(sensitivity + specificity - 1.)

    ifp = (float(tp + fp) / tp) if tp > 0 else -np.inf

    accuracy = (tp + tn) / (tp + tn + fp + fn)
    
    row = pd.DataFrame({title: [t], 'AUC': auc, 'Overall Accuracy': accuracy, 
                        'Precision': precision, 'Sensitivity': sensitivity, 'Specificity': specificity,
                        'KS': ks, 'IFP': ifp})
    
    return row

# %%
def optimize_threshold(y_true, y_):

    t, max_metric = None, -np.inf

    for i in np.arange(0.00, max(y_), 0.01):

        y_hat = np.copy(y_)

        filter__ = y_hat >= i

        y_hat[filter__], y_hat[~filter__] = 1, 0

        tn, fp, fn, tp = confusion_matrix(y_true, y_hat).ravel()

        sensitivity = (tp / float(tp + fn)) if tp + fn > 0 else 1

        specificity = (tn / float(tn + fp)) if tn + fp > 0 else 1

        ks = abs(sensitivity + specificity - 1.)
        
        auc = roc_auc_score(y_true, y_hat)
        
        metric = ks

        if metric > max_metric and metric is not np.inf:

            max_metric = metric

            t = i

    return t

# %%
from scipy.special import erfinv

class GaussRankScaler():

    def __init__( self ):
        self.epsilon = 0.001
        self.lower = -1 + self.epsilon
        self.upper = 1 - self.epsilon
        self.range = self.upper - self.lower
        self.mean = None

    def fit_transform( self, X ):

        i = np.argsort( X, axis = 0 )
        j = np.argsort( i, axis = 0 )

        assert ( j.min() == 0 ).all()
        assert ( j.max() == len( j ) - 1 ).all()

        j_range = len( j ) - 1
        self.divider = j_range / self.range

        transformed = j / self.divider
        transformed = transformed - self.upper
        transformed = erfinv( transformed )
        
        self.mean = np.mean(X, axis=0)

        return transformed - self.mean
    
    def transform( self, X ):

        i = np.argsort( X, axis = 0 )
        j = np.argsort( i, axis = 0 )

        assert ( j.min() == 0 ).all()
        assert ( j.max() == len( j ) - 1 ).all()

        j_range = len( j ) - 1
        self.divider = j_range / self.range

        transformed = j / self.divider
        transformed = transformed - self.upper
        transformed = erfinv( transformed )

        return transformed - self.mean

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report
from datetime import datetime
import lightgbm as lgb
import numpy as np

kfold = StratifiedKFold(10, random_state=13)

index = []

result, detailed_result = None, None

for ic, col in enumerate(dataset.columns[1:]):
    
    all_ = None
    
    dat = dataset[[dataset.columns[0], col]].copy().join(therapy.dropna(), how='inner')
    
    for column in dat:

        if dat[column].dtype == 'object':

            values = pd.get_dummies(dat[column])

            values.columns = [column + '_' + str(col) for col in values.columns]
        else:
            values = dat[column].fillna(0)

        all_ = values if all_ is None else pd.concat([all_, values], axis=1)
        
    x = all_.values[:,1:]

    y = all_.values[:,0]

    for i, (train_index, valid_index) in enumerate(kfold.split(x, y)):

        s = GaussRankScaler()

        x_train, y_train = s.fit_transform(x[train_index,:]), y[train_index].ravel()

        x_valid, y_valid = s.transform(x[valid_index,:]), y[valid_index].ravel()

        lgb_train = lgb.Dataset(x_train, y_train)

        params = {'boosting_type': 'gbdt', 
                  'objective': 'binary',
                  'num_class': 1,
                  'metric': 'logloss',
                  'learning_rate': 0.01, 
                  'num_leaves': 31, 
                  'max_depth': 4,  
                  'min_child_samples': 20, 
                  'max_bin': 255,  
                  'subsample': 0.8, 
                  'subsample_freq': 0,  
                  'colsample_bytree': 0.3,  
                  'min_child_weight': 5, 
                  'subsample_for_bin': 200000,
                  'min_split_gain': 0, 
                  'reg_alpha': 0, 
                  'reg_lambda': 0, 
                  'nthread': 6, 
                  'verbose': 0}

        gbm = lgb.train(params, lgb_train, num_boost_round=1000)    

        y_ = gbm.predict(x_valid)

        #
        #
        #
        auc = roc_auc_score(y_valid, y_)

        t = optimize_threshold(y_train, gbm.predict(x_train))

        tn, fp, fn, tp = confusion_matrix(y_valid, [int(y >= t) for y in y_]).ravel()

        row = generate_metric(i + 1, auc, tn, fp, fn, tp, title='Fold')

        row['Threshold'] = t

        result = row if result is None else pd.concat([result, row])
        
        detailed_row = pd.DataFrame({'fold': i + 1, 'variable': col, 'y_opt': [int(y >= t) for y in y_], 
                                     'y_hat': [max(min(1, yy), 0) for yy in y_ * .5 / t], 'y': list(y_valid), 
                                     'class': list(therapy_class[valid_index])}, index=list(dataset.index[valid_index]))
        
        detailed_result = detailed_row if detailed_result is None else pd.concat([detailed_row, detailed_result])
        
        index.append(col)
        
result.index = index

result
# Out:
#                       Fold       AUC  Overall Accuracy  Precision  \
# lgh                      1  0.657452          0.691176   0.368421
# lgh                      2  0.530048          0.588235   0.227273
# lgh                      3  0.567308          0.676471   0.285714
# lgh                      4  0.727163          0.705882   0.388889
# lgh                      5  0.741026          0.611940   0.310345
# lgh                      6  0.602564          0.641791   0.304348
# lgh                      7  0.641830          0.590909   0.269231
# lgh                      8  0.750327          0.727273   0.421053
# lgh                      9  0.745098          0.727273   0.421053
# lgh                     10  0.584314          0.666667   0.266667
# lgl                      1  0.635817          0.632353   0.344828
# lgl                      2  0.526442          0.588235   0.200000
# lgl                      3  0.453125          0.558824   0.062500
# lgl                      4  0.617788          0.691176   0.368421
# lgl                      5  0.639744          0.656716   0.250000
# lgl                      6  0.619231          0.686567   0.350000
# lgl                      7  0.564706          0.636364   0.263158
# lgl                      8  0.784314          0.818182   0.600000
# lgl                      9  0.662745          0.636364   0.304348
# lgl                     10  0.626144          0.696970   0.333333
# percent_aneuploid        1  0.629808          0.544118   0.285714
# percent_aneuploid        2  0.600962          0.588235   0.269231
# percent_aneuploid        3  0.627404          0.661765   0.294118
# percent_aneuploid        4  0.615385          0.573529   0.275862
# percent_aneuploid        5  0.664103          0.701493   0.368421
# percent_aneuploid        6  0.535897          0.626866   0.187500
# percent_aneuploid        7  0.647059          0.666667   0.360000
# percent_aneuploid        8  0.713725          0.727273   0.444444
# percent_aneuploid        9  0.660131          0.606061   0.296296
# percent_aneuploid       10  0.546405          0.621212   0.222222
# ...                    ...       ...               ...        ...
# lgm                      1  0.574519          0.514706   0.206897
# lgm                      2  0.616587          0.588235   0.285714
# lgm                      3  0.564904          0.573529   0.240000
# lgm                      4  0.664663          0.720588   0.428571
# lgm                      5  0.742308          0.731343   0.428571
# lgm                      6  0.634615          0.641791   0.320000
# lgm                      7  0.620915          0.651515   0.318182
# lgm                      8  0.728105          0.636364   0.354839
# lgm                      9  0.720261          0.636364   0.333333
# lgm                     10  0.501961          0.636364   0.235294
# m_protein                1  0.633413          0.617647   0.291667
# m_protein                2  0.534856          0.632353   0.235294
# m_protein                3  0.536058          0.647059   0.250000
# m_protein                4  0.663462          0.676471   0.363636
# m_protein                5  0.632051          0.656716   0.300000
# m_protein                6  0.603846          0.552239   0.258065
# m_protein                7  0.641830          0.651515   0.333333
# lgm                      0.733333     0.607843  0.341176   2.818182       0.23
# lgm                      0.600000     0.647059  0.247059   3.000000       0.26
# lgm                      0.266667     0.745098  0.011765   4.250000       0.31
# m_protein                0.437500     0.673077  0.110577   3.428571       0.27
# m_protein                0.250000     0.750000  0.000000   4.250000       0.25
# m_protein                0.250000     0.769231  0.019231   4.000000       0.30
# m_protein                0.500000     0.730769  0.230769   2.750000       0.26
# m_protein                0.400000     0.730769  0.130769   3.333333       0.26
# m_protein                0.533333     0.557692  0.091026   3.875000       0.22
# m_protein                0.533333     0.686275  0.219608   3.000000       0.24
# m_protein                0.600000     0.725490  0.325490   2.555556       0.24
# m_protein                0.733333     0.627451  0.360784   2.727273       0.25
# m_protein                0.333333     0.725490  0.058824   3.800000       0.27
# first_line_transpant     0.500000     0.692308  0.192308   3.000000       0.28
# first_line_transpant     0.375000     0.750000  0.125000   3.166667       0.25
# first_line_transpant     0.625000     0.730769  0.355769   2.400000       0.27
# first_line_transpant     0.500000     0.884615  0.384615   1.750000       0.34
# first_line_transpant     0.800000     0.730769  0.530769   2.166667       0.27
# first_line_transpant     0.666667     0.673077  0.339744   2.700000       0.25
# first_line_transpant     0.666667     0.529412  0.196078   3.400000       0.20
# first_line_transpant     0.733333     0.725490  0.458824   2.272727       0.25
# first_line_transpant     0.733333     0.627451  0.360784   2.727273       0.21
# first_line_transpant     0.266667     0.686275  0.047059   5.000000       0.29
#
# [510 rows x 9 columns]

# %%
result_mean = result.groupby(level=0).mean()

del result_mean['Fold']

result_mean.to_csv('output/nogen_overall.tsv', sep='\t')

result_mean
# Out:
#                                              AUC  Overall Accuracy  Precision  \
# 11p15                                   0.627174          0.654005   0.313909
# 13q14                                   0.656573          0.640612   0.330349
# 13q34                                   0.611277          0.653782   0.308152
# 15q15                                   0.631243          0.630163   0.308233
# 17p13                                   0.617959          0.640368   0.312376
# 19q13                                   0.609507          0.629917   0.296198
# 1q21                                    0.615060          0.623078   0.291459
# 20q13                                   0.640413          0.677865   0.360981
# 21q22                                   0.619023          0.628650   0.296928
# 3q21                                    0.631009          0.658639   0.332717
# 5q31                                    0.629496          0.642440   0.320382
# 7q22                                    0.641034          0.656923   0.333347
# 9q33                                    0.603853          0.618248   0.294979
# absolute_neutrophil                     0.640108          0.661825   0.344468
# age                                     0.664585          0.661648   0.350328
# albumin                                 0.643937          0.662961   0.334352
# beta_2_microglobulin                    0.667758          0.693975   0.354471
# bun                                     0.633112          0.661557   0.332816
# calcium                                 0.630541          0.674836   0.334282
# creatinine                              0.656362          0.664164   0.342547
# family_cancer                           0.619920          0.653445   0.323912
# first_line_transpant                    0.690778          0.675704   0.376991
# gender                                  0.612815          0.643243   0.302804
# glucose                                 0.613495          0.646874   0.304790
# hemoglobin                              0.611445          0.637717   0.293705
# hyperdiploid_flag                       0.605715          0.631746   0.293745
# iss                                     0.608679          0.655784   0.313924
# ldh                                     0.629077          0.695579   0.346880
# lga                                     0.631747          0.648011   0.309538
# lgg                                     0.626956          0.670515   0.338027
# lgh                                     0.654713          0.662762   0.326299
# t_12_14_ccnd2                              0.461667     0.717270  0.178937
# t_14_16_maf                                0.435833     0.728959  0.164793
# t_14_20_mafb                               0.442500     0.722926  0.176965
# t_4_14_whsc1                               0.521667     0.721192  0.242858
# t_6_14_ccnd3                               0.413750     0.703846  0.144776
# t_8_14_mafa                                0.455417     0.659238  0.131963
# t_8_14_myc                                 0.461250     0.728959  0.201190
# total_protein                              0.404167     0.754110  0.165969
# wbc_x10_10_9_l                             0.422083     0.717308  0.191589
#
#                                              IFP  Threshold
# 11p15                                   3.892381      0.266
# 13q14                                   3.270534      0.263
# 13q34                                   3.590000      0.269
# 15q15                                   3.318611      0.253
# 17p13                                   3.347186      0.262
# 19q13                                   3.520714      0.267
# 1q21                                    3.701746      0.269
# 20q13                                   2.860238      0.273
# 21q22                                   3.437698      0.266
# 3q21                                    3.191468      0.271
# 5q31                                    3.426840      0.269
# 7q22                                    3.216587      0.265
# 9q33                                    3.672439      0.261
# absolute_neutrophil                     3.133344      0.263
# age                                     3.059722      0.267
# albumin                                 3.278452      0.277
# beta_2_microglobulin                    3.597619      0.294
# bun                                     3.127500      0.268
# calcium                                 3.231548      0.291
# creatinine                              3.054365      0.268
# family_cancer                           3.223016      0.263
# first_line_transpant                    2.858333      0.261
# gender                                  3.510516      0.267
# glucose                                 3.587698      0.272
# hemoglobin                              3.775317      0.259
# hyperdiploid_flag                       3.627976      0.271
# iss                                     3.509524      0.278
# ldh                                     3.068095      0.288
# lga                                     3.434816      0.270
# lgg                                     3.093889      0.277
# lgh                                     3.190794      0.281
# lgl                                     4.522381      0.278
# lgl_kappa                               3.264167      0.270
# lgl_lambda                              3.194167      0.261
# lgm                                     3.350271      0.257
# m_protein                               3.371973      0.256
# percent_aneuploid                       3.518968      0.259
# percent_plama_cells_bone_marrow         4.037619      0.264
# percent_plama_cells_peripherical_blood  3.437424      0.286
# platelet                                3.334246      0.265
# race                                    3.505833      0.256
# t_11_14_ccnd1                           3.371825      0.268
# t_12_14_ccnd2                           3.098413      0.271
# t_14_16_maf                             3.247781      0.262
# t_14_20_mafb                            3.302302      0.272
# t_4_14_whsc1                            2.878434      0.274
# t_6_14_ccnd3                            3.711111      0.269
# t_8_14_mafa                             3.626912      0.254
# t_8_14_myc                              3.142857      0.273
# total_protein                           3.168175      0.291
# wbc_x10_10_9_l                          3.836508      0.271

# %%
def compute_all(x):
    
    a = None
    
    try:
        a = roc_auc_score(x['y_opt'], x['y'])
    except:
        a = np.inf
    
    try:
        tn, fp, fn, tp = confusion_matrix(x['y'], x['y_opt']).ravel()
    except:
        tn, fp, fn, tp = np.inf,np.inf,np.inf,np.inf

    result = {'auc': a, 'tn': tn, 'fp': fp, 'fn': fn, 'tp': tp}
    
    row = generate_metric(i + 1, auc, tn, fp, fn, tp, title='Fold')
    
    for c in row:
        result[c] = row[c][0]
    
    return pd.Series(result)    
    
detailed = detailed_result.groupby(['class', 'variable']).apply(compute_all)

detailed
# Out:
#                                                               auc    tn    fp  \
# class            variable
# Bortezomib-based 11p15                                   0.605382  75.0  34.0
#                  13q14                                   0.612051  74.0  35.0
#                  19q13                                   13.0  19.0  10.0
#                  1q21                                    17.0  15.0  10.0
#                  20q13                                   13.0  19.0  10.0
#                  21q22                                   15.0  17.0  10.0
#                  3q21                                    13.0  19.0  10.0
#                  5q31                                    15.0  17.0  10.0
#                  7q22                                    15.0  17.0  10.0
#                  9q33                                    15.0  17.0  10.0
#                  absolute_neutrophil                     15.0  17.0  10.0
#                  age                                     13.0  19.0  10.0
#                  albumin                                 17.0  15.0  10.0
#                  beta_2_microglobulin                    19.0  13.0  10.0
#                  bun                                     17.0  15.0  10.0
#                  calcium                                 18.0  14.0  10.0
#                  creatinine                              16.0  16.0  10.0
#                  family_cancer                           16.0  16.0  10.0
#                  first_line_transpant                    10.0  22.0  10.0
#                  gender                                  16.0  16.0  10.0
#                  glucose                                 13.0  19.0  10.0
#                  hemoglobin                              18.0  14.0  10.0
#                  hyperdiploid_flag                       16.0  16.0  10.0
#                  iss                                     18.0  14.0  10.0
#                  ldh                                     17.0  15.0  10.0
#                  lga                                     14.0  18.0  10.0
#                  lgg                                     19.0  13.0  10.0
# ...                                                       ...   ...   ...
# IMIDs-based      first_line_transpant                     6.0   7.0  10.0
#                  gender                                   7.0   6.0  10.0
#                  glucose                                  7.0   6.0  10.0
#                  hemoglobin                               8.0   5.0  10.0
#                  hyperdiploid_flag                        5.0   8.0  10.0
#                  iss                                      6.0   7.0  10.0
#                  ldh                                      7.0   6.0  10.0
#                  lga                                      7.0   6.0  10.0
#                  lgg                                      6.0   7.0  10.0
#                  lgh                                      6.0   7.0  10.0
#                  lgl                                      8.0   5.0  10.0
#                  lgl_kappa                                7.0   6.0  10.0
#                  lgl_lambda                               5.0   8.0  10.0
#                  lgm                                      7.0   6.0  10.0
#                  m_protein                                7.0   6.0  10.0
#                  percent_aneuploid                        6.0   7.0  10.0
#                  percent_plama_cells_bone_marrow          8.0   5.0  10.0
#                  percent_plama_cells_peripherical_blood   7.0   6.0  10.0
#                  platelet                                 8.0   5.0  10.0
#                  race                                     8.0   5.0  10.0
#                  t_11_14_ccnd1                            8.0   5.0  10.0
#                  t_12_14_ccnd2                            8.0   5.0  10.0
#                  t_14_16_maf                              8.0   5.0  10.0
#                  t_14_20_mafb                             8.0   5.0  10.0
#                  t_4_14_whsc1                             7.0   6.0  10.0
#                  t_6_14_ccnd3                             7.0   6.0  10.0
#                  t_8_14_mafa                              8.0   5.0  10.0
#                  t_8_14_myc                               8.0   5.0  10.0
#                  total_protein                           11.0   2.0  10.0
#                  wbc_x10_10_9_l                           7.0   6.0  10.0
#
#                                                               AUC  \
# class            variable
# Bortezomib-based 11p15                                   0.568627
#                  13q14                                   0.568627
#                  13q34                                   0.568627
#                  15q15                                   0.568627
#                  17p13                                   0.568627
#                  19q13                                   0.568627
#                  1q21                                    0.568627
#                  20q13                                   0.568627
#                  21q22                                   0.568627
#                  3q21                                    0.568627
#                  5q31                                    0.568627
#                  7q22                                    0.568627
#                  9q33                                    0.568627
#                  absolute_neutrophil                     0.568627
#                  age                                     0.568627
#                  albumin                                 0.568627
#                  beta_2_microglobulin                    0.568627
#                  bun                                     0.568627
#                  calcium                                 0.568627
#                  creatinine                              0.568627
#                  family_cancer                           0.568627
#                  first_line_transpant                    0.568627
#                  gender                                  0.568627
#                  glucose                                 0.568627
#                  hemoglobin                              0.568627
#                  hyperdiploid_flag                       0.568627
#                  iss                                     0.568627
#                  ldh                                     0.568627
#                  lga                                     0.568627
#                  lgg                                     0.568627
# ...                                                           ...
# IMIDs-based      first_line_transpant                    0.568627
#                  gender                                  0.568627
#                  glucose                                 0.568627
#                  hemoglobin                              0.568627
#                  hyperdiploid_flag                       0.568627
#                  iss                                     0.568627
#                  ldh                                     0.568627
#                  lga                                     0.568627
#                  lgg                                     0.568627
#                  lgh                                     0.568627
#                  lgl                                     0.568627
#                  lgl_kappa                               0.568627
#                  lgl_lambda                              0.568627
#                  lgm                                     0.568627
#                  m_protein                               0.568627
#                  percent_aneuploid                       0.568627
#                  percent_plama_cells_bone_marrow         0.568627
#                  percent_plama_cells_peripherical_blood  0.568627
#                  platelet                                0.568627
#                  race                                    0.568627
#                  t_11_14_ccnd1                           0.568627
#                  t_12_14_ccnd2                           0.568627
#                  t_14_16_maf                             0.568627
#                  t_14_20_mafb                            0.568627
#                  t_4_14_whsc1                            0.568627
#                  t_6_14_ccnd3                            0.568627
#                  t_8_14_mafa                             0.568627
#                  t_8_14_myc                              0.568627
#                  total_protein                           0.568627
#                  wbc_x10_10_9_l                          0.568627
#
#                                                          Overall Accuracy  \
# class            variable
# Bortezomib-based 11p15                                           0.666667
#                  13q14                                           0.666667
#                  13q34                                           0.673759
#                  15q15                                           0.659574
#                  17p13                                           0.680851
#                  19q13                                           0.659574
#                  1q21                                            0.652482
#                  20q13                                           0.716312
#                  21q22                                           0.666667
#                  3q21                                            0.687943
#                  5q31                                            0.702128
#                  7q22                                            0.680851
#                  9q33                                            0.666667
#                  absolute_neutrophil                             0.652482
#                  age                                             0.673759
#                  albumin                                         0.687943
#                  beta_2_microglobulin                            0.695035
#                  bun                                             0.659574
#                  calcium                                         0.673759
#                  creatinine                                      0.624113
#                  family_cancer                                   0.645390
#                  first_line_transpant                            0.652482
#                  gender                                          0.645390
#                  glucose                                         0.645390
#                  hemoglobin                                      0.609929
#                  hyperdiploid_flag                               0.680851
#                  iss                                             0.631206
#                  ldh                                             0.730496
#                  lga                                             0.695035
#                  lgg                                             0.673759
# ...                                                                   ...
# IMIDs-based      first_line_transpant                            0.767857
#                  gender                                          0.642857
#                  glucose                                         0.678571
#                  hemoglobin                                      0.625000
#                  hyperdiploid_flag                               0.678571
#                  iss                                             0.750000
#                  ldh                                             0.678571
#                  lga                                             0.607143
#                  lgg                                             0.696429
#                  lgh                                             0.625000
#                  lgl                                             0.678571
#                  lgl_kappa                                       0.589286
#                  lgl_lambda                                      0.660714
#                  lgm                                             0.607143
#                  m_protein                                       0.607143
#                  percent_aneuploid                               0.607143
#                  percent_plama_cells_bone_marrow                 0.678571
#                  percent_plama_cells_peripherical_blood          0.678571
#                  platelet                                        0.642857
#                  race                                            0.660714
#                  t_11_14_ccnd1                                   0.660714
#                  t_12_14_ccnd2                                   0.625000
#                  t_14_16_maf                                     0.660714
#                  t_14_20_mafb                                    0.660714
#                  t_4_14_whsc1                                    0.678571
#                  t_6_14_ccnd3                                    0.589286
#                  t_8_14_mafa                                     0.607143
#                  t_8_14_myc                                      0.589286
#                  total_protein                                   0.642857
#                  wbc_x10_10_9_l                                  0.642857
#
#                                                          Precision  \
# class            variable
# Bortezomib-based 11p15                                    0.358491
#                  13q14                                    0.363636
#                  13q34                                    0.340909
#                  15q15                                    0.333333
#                  17p13                                    0.372549
#                  19q13                                    0.351852
#                  1q21                                     0.319149
#                  20q13                                    0.413043
#                  21q22                                    0.346939
#                  3q21                                     0.380000
#                  5q31                                     0.386364
#                  7q22                                     0.361702
#                  9q33                                     0.346939
#                  absolute_neutrophil                      0.333333
#                  age                                      0.365385
#                  albumin                                  0.357143
#                  beta_2_microglobulin                     0.351351
#                  bun                                      0.326087
#                  calcium                                  0.333333
#                  creatinine                               0.301887
#                  family_cancer                            0.320000
#                  first_line_transpant                     0.360656
#                  gender                                   0.320000
#                  glucose                                  0.339286
#                  hemoglobin                               0.274510
#                  hyperdiploid_flag                        0.355556
#                  iss                                      0.291667
#                  ldh                                      0.416667
#                  lga                                      0.382979
#                  lgg                                      0.325000
# ...                                                            ...
# IMIDs-based      first_line_transpant                     0.500000
#                  gender                                   0.315789
#                  glucose                                  0.352941
#                  hemoglobin                               0.277778
#                  hyperdiploid_flag                        0.380952
#                  iss                                      0.466667
#                  ldh                                      0.352941
#                  lga                                      0.285714
#                  lgg                                      0.388889
#                  lgh                                      0.318182
#                  lgl                                      0.333333
#                  lgl_kappa                                0.272727
#                  lgl_lambda                               0.363636
#                  lgm                                      0.285714
#                  m_protein                                0.285714
#                  percent_aneuploid                        0.304348
#                  percent_plama_cells_bone_marrow          0.333333
#                  percent_plama_cells_peripherical_blood   0.352941
#                  platelet                                 0.294118
#                  race                                     0.312500
#                  t_11_14_ccnd1                            0.312500
#                  t_12_14_ccnd2                            0.277778
#                  t_14_16_maf                              0.312500
#                  t_14_20_mafb                             0.312500
#                  t_4_14_whsc1                             0.352941
#                  t_6_14_ccnd3                             0.272727
#                  t_8_14_mafa                              0.263158
#                  t_8_14_myc                               0.250000
#                  total_protein                            0.181818
#                  wbc_x10_10_9_l                           0.315789
#
#                                                          Sensitivity  \
# class            variable
# Bortezomib-based 11p15                                      0.593750
#                  13q14                                      0.625000
#                  13q34                                      0.468750
#                  15q15                                      0.500000
#                  17p13                                      0.593750
#                  19q13                                      0.593750
#                  1q21                                       0.468750
#                  20q13                                      0.593750
#                  21q22                                      0.531250
#                  3q21                                       0.593750
#                  5q31                                       0.531250
#                  7q22                                       0.531250
#                  9q33                                       0.531250
#                  absolute_neutrophil                        0.531250
#                  age                                        0.593750
#                  albumin                                    0.468750
#                  beta_2_microglobulin                       0.406250
#                  bun                                        0.468750
#                  calcium                                    0.437500
#                  creatinine                                 0.500000
#                  family_cancer                              0.500000
#                  first_line_transpant                       0.687500
#                  gender                                     0.500000
#                  glucose                                    0.593750
#                  hemoglobin                                 0.437500
#                  hyperdiploid_flag                          0.500000
#                  iss                                        0.437500
#                  ldh                                        0.468750
#                  lga                                        0.562500
#                  lgg                                        0.406250
# ...                                                              ...
# IMIDs-based      first_line_transpant                       0.538462
#                  gender                                     0.461538
#                  glucose                                    0.461538
#                  hemoglobin                                 0.384615
#                  hyperdiploid_flag                          0.615385
#                  iss                                        0.538462
#                  ldh                                        0.461538
#                  lga                                        0.461538
#                  lgg                                        0.538462
#                  lgh                                        0.538462
#                  lgl                                        0.384615
#                  lgl_kappa                                  0.461538
#                  lgl_lambda                                 0.615385
#                  lgm                                        0.461538
#                  m_protein                                  0.461538
#                  percent_aneuploid                          0.538462
#                  percent_plama_cells_bone_marrow            0.384615
#                  percent_plama_cells_peripherical_blood     0.461538
#                  platelet                                   0.384615
#                  race                                       0.384615
#                  t_11_14_ccnd1                              0.384615
#                  t_12_14_ccnd2                              0.384615
#                  t_14_16_maf                                0.384615
#                  t_14_20_mafb                               0.384615
#                  t_4_14_whsc1                               0.461538
#                  t_6_14_ccnd3                               0.461538
#                  t_8_14_mafa                                0.384615
#                  t_8_14_myc                                 0.384615
#                  total_protein                              0.153846
#                  wbc_x10_10_9_l                             0.461538
#
#                                                          Specificity  \
# class            variable
# Bortezomib-based 11p15                                      0.688073
#                  13q14                                      0.678899
#                  13q34                                      0.733945
#                  15q15                                      0.706422
#                  17p13                                      0.706422
#                  19q13                                      0.678899
#                  1q21                                       0.706422
#                  20q13                                      0.752294
#                  21q22                                      0.706422
#                  3q21                                       0.715596
#                  5q31                                       0.752294
#                  7q22                                       0.724771
#                  9q33                                       0.706422
#                  absolute_neutrophil                        0.688073
#                  age                                        0.697248
#                  albumin                                    0.752294
#                  beta_2_microglobulin                       0.779817
#                  bun                                        0.715596
#                  calcium                                    0.743119
#                  creatinine                                 0.660550
#                  family_cancer                              0.688073
#                  first_line_transpant                       0.642202
#                  gender                                     0.688073
#                  glucose                                    0.660550
#                  hemoglobin                                 0.660550
#                  hyperdiploid_flag                          0.733945
#                  iss                                        0.688073
#                  ldh                                        0.807339
#                  lga                                        0.733945
#                  lgg                                        0.752294
# ...                                                              ...
# IMIDs-based      first_line_transpant                       0.837209
#                  gender                                     0.697674
#                  glucose                                    0.744186
#                  hemoglobin                                 0.697674
#                  hyperdiploid_flag                          0.697674
#                  iss                                        0.813953
#                  ldh                                        0.744186
#                  lga                                        0.651163
#                  lgg                                        0.744186
#                  lgh                                        0.651163
#                  lgl                                        0.767442
#                  lgl_kappa                                  0.627907
#                  lgl_lambda                                 0.674419
#                  lgm                                        0.651163
#                  m_protein                                  0.651163
#                  percent_aneuploid                          0.627907
#                  percent_plama_cells_bone_marrow            0.767442
#                  percent_plama_cells_peripherical_blood     0.744186
#                  platelet                                   0.720930
#                  race                                       0.744186
#                  t_11_14_ccnd1                              0.744186
#                  t_12_14_ccnd2                              0.697674
#                  t_14_16_maf                                0.744186
#                  t_14_20_mafb                               0.744186
#                  t_4_14_whsc1                               0.744186
#                  t_6_14_ccnd3                               0.627907
#                  t_8_14_mafa                                0.674419
#                  t_8_14_myc                                 0.651163
#                  total_protein                              0.790698
#                  wbc_x10_10_9_l                             0.697674
#
#                                                                KS       IFP
# class            variable
# Bortezomib-based 11p15                                   0.281823  2.789474
#                  13q14                                   0.303899  2.750000
#                  13q34                                   0.202695  2.933333
#                  15q15                                   0.206422  3.000000
#                  17p13                                   0.300172  2.684211
#                  19q13                                   0.272649  2.842105
#                  1q21                                    0.175172  3.133333
#                  20q13                                   0.346044  2.421053
#                  21q22                                   0.237672  2.882353
#                  3q21                                    0.309346  2.631579
#                  5q31                                    0.283544  2.588235
#                  7q22                                    0.256021  2.764706
#                  9q33                                    0.237672  2.882353
#                  absolute_neutrophil                     0.219323  3.000000
#                  age                                     0.290998  2.736842
#                  albumin                                 0.221044  2.800000
#                  beta_2_microglobulin                    0.186067  2.846154
#                  bun                                     0.184346  3.066667
#                  calcium                                 0.180619  3.000000
#                  creatinine                              0.160550  3.312500
#                  family_cancer                           0.188073  3.125000
#                  first_line_transpant                    0.329702  2.772727
#                  gender                                  0.188073  3.125000
#                  glucose                                 0.254300  2.947368
#                  hemoglobin                              0.098050  3.642857
#                  hyperdiploid_flag                       0.233945  2.812500
#                  iss                                     0.125573  3.428571
#                  ldh                                     0.276089  2.400000
#                  lga                                     0.296445  2.611111
#                  lgg                                     0.158544  3.076923
# ...                                                           ...       ...
# IMIDs-based      first_line_transpant                    0.375671  2.000000
#                  gender                                  0.159213  3.166667
#                  glucose                                 0.205725  2.833333
#                  hemoglobin                              0.082290  3.600000
#                  hyperdiploid_flag                       0.313059  2.625000
#                  iss                                     0.352415  2.142857
#                  ldh                                     0.205725  2.833333
#                  lga                                     0.112701  3.500000
#                  lgg                                     0.282648  2.571429
#                  lgh                                     0.189624  3.142857
#                  lgl                                     0.152057  3.000000
#                  lgl_kappa                               0.089445  3.666667
#                  lgl_lambda                              0.289803  2.750000
#                  lgm                                     0.112701  3.500000
#                  m_protein                               0.112701  3.500000
#                  percent_aneuploid                       0.166369  3.285714
#                  percent_plama_cells_bone_marrow         0.152057  3.000000
#                  percent_plama_cells_peripherical_blood  0.205725  2.833333
#                  platelet                                0.105546  3.400000
#                  race                                    0.128801  3.200000
#                  t_11_14_ccnd1                           0.128801  3.200000
#                  t_12_14_ccnd2                           0.082290  3.600000
#                  t_14_16_maf                             0.128801  3.200000
#                  t_14_20_mafb                            0.128801  3.200000
#                  t_4_14_whsc1                            0.205725  2.833333
#                  t_6_14_ccnd3                            0.089445  3.666667
#                  t_8_14_mafa                             0.059034  3.800000
#                  t_8_14_myc                              0.035778  4.000000
#                  total_protein                           0.055456  5.500000
#                  wbc_x10_10_9_l                          0.159213  3.166667
#
# [204 rows x 13 columns]

# %%
detailed = detailed.reset_index().set_index('variable')

for class_ in detailed['class'].unique():
    
    current_class = detailed.loc[detailed['class'] == class_].iloc[:,1:]
    
    current_class.to_csv('output/nogen_{}.tsv'.format(class_.lower().replace(' ', '_').replace('/', '_')))
