# %% [markdown]
# # Loading Data

# %%
from data import load_data
import numpy as np

clinical, _, genes, treatments, outcome = load_data()

print(clinical.shape)

clinical.describe().T
# Out:
# (724, 35)
#                                         count         mean          std  \
# cmmc                                    376.0  5907.877660  9307.921203
# ecog_ps                                 357.0     1.330532     0.638197
# percent_aneuploid                       539.0    18.178948    21.639551
# percent_plama_cells_bone_marrow         616.0    17.599838    16.658980
# percent_plama_cells_peripherical_blood  616.0     0.636519     2.831528
# creatinine                              710.0   106.869476    62.670669
# iss                                     704.0     1.917614     0.799379
# absolute_neutrophil                     707.0     3.912428     2.173153
# platelet                                723.0   220.117566    79.182326
# wbc_x10_10_9_l                          616.0     6.271688     2.517359
# bun                                     560.0     7.721511     4.347456
# glucose                                 605.0     5.934057     1.795880
# total_protein                           600.0     9.037900     1.965543
# albumin                                 715.0    36.227958     6.277799
# beta_2_microglobulin                    608.0     3.609773     1.805297
# calcium                                 716.0     2.387308     0.279937
# hemoglobin                              724.0     6.702294     1.197662
# ldh                                     595.0     3.394684     1.725845
# age                                     724.0    62.642265    10.679562
# gender                                  724.0     0.404696     0.491172
# lga                                     480.0     0.818242     2.039371
# lgg                                     579.0    31.072494    27.274694
# lgl_kappa                               454.0     7.833722    11.568938
# lgl_lambda                              584.0     9.783835    22.091727
# lgm                                     573.0     0.240679     0.198871
# m_protein                               604.0     2.470891     1.608719
# first_line_transplant                   724.0     0.519337     0.499971
# cell_markers_cd117                      724.0     0.465470     0.499151
# cell_markers_cd13                       724.0     0.049724     0.217524
# cell_markers_cd138                      724.0     0.331492     0.471075
# cell_markers_cd38                       724.0     0.001381     0.037165
# race_asian                              724.0     0.016575     0.127759
# race_black_african_american             724.0     0.132597     0.339373
# race_other                              724.0     0.045580     0.208717
# race_white                              724.0     0.657459     0.474888
#
#                                              min        25%         50%  \
# cmmc                                     0.00000  233.25000  1409.50000
# ecog_ps                                  1.00000    1.00000     1.00000
# percent_aneuploid                        0.00000    0.00000    10.00000
# percent_plama_cells_bone_marrow          0.00000    5.70000    11.60000
# percent_plama_cells_peripherical_blood   0.00000    0.00000     0.00000
# creatinine                              33.00000   70.72000    88.40000
# iss                                      1.00000    1.00000     2.00000
# absolute_neutrophil                      0.58000    2.40000     3.50000
# platelet                                18.00000  167.00000   215.00000
# wbc_x10_10_9_l                           1.40000    4.50000     5.90000
# bun                                      1.78500    4.99800     6.78300
# glucose                                  0.00473    5.00500     5.61000
# total_protein                            4.50000    7.50000     9.00000
# albumin                                 20.00000   32.00000    36.10000
# beta_2_microglobulin                     0.10000    2.34000     3.20000
# calcium                                  0.93000    2.22750     2.35000
# hemoglobin                               3.41000    5.82800     6.57200
# ldh                                      0.16670    2.31713     2.90058
# age                                     27.00000   56.00000    63.00000
# gender                                   0.00000    0.00000     0.00000
# lga                                      0.04000    0.18375     0.31000
# lgg                                      0.91000    5.20000    26.10000
# lgl_kappa                                0.00000    0.62625     1.97500
# lgl_lambda                               0.00000    0.36075     0.82300
# lgm                                      0.00000    0.11000     0.19900
# m_protein                                0.00000    1.19675     2.54500
# first_line_transplant                    0.00000    0.00000     1.00000
# cell_markers_cd117                       0.00000    0.00000     0.00000
# cell_markers_cd13                        0.00000    0.00000     0.00000
# cell_markers_cd138                       0.00000    0.00000     0.00000
# cell_markers_cd38                        0.00000    0.00000     0.00000
# race_asian                               0.00000    0.00000     0.00000
# race_black_african_american              0.00000    0.00000     0.00000
# race_other                               0.00000    0.00000     0.00000
# race_white                               0.00000    0.00000     1.00000
#
#                                                 75%          max
# cmmc                                    7145.500000  47146.00000
# ecog_ps                                    1.000000      4.00000
# percent_aneuploid                         29.700000     89.40000
# percent_plama_cells_bone_marrow           23.225000     84.30000
# percent_plama_cells_peripherical_blood     0.100000     33.30000
# creatinine                               116.688000    503.88000
# iss                                        3.000000      3.00000
# absolute_neutrophil                        4.760000     16.51200
# platelet                                 262.000000    668.00000
# wbc_x10_10_9_l                             7.500000     25.80000
# bun                                        8.576000     34.98600
# glucose                                    6.325000     16.94000
# total_protein                             10.300000     16.40000
# albumin                                   40.750000     54.00000
# beta_2_microglobulin                       4.700000      8.20000
# calcium                                    2.500000      3.52500
# hemoglobin                                 7.564000      9.98200
# ldh                                        3.817430     13.93612
# age                                       70.000000     93.00000
# gender                                     1.000000      1.00000
# lga                                        0.600000     15.90000
# lgg                                       51.020000    111.40000
# lgl_kappa                                  9.722499     49.61000
# lgl_lambda                                 4.445000    120.53000
# lgm                                        0.300000      1.75000
# m_protein                                  3.770000      5.55000
# first_line_transplant                      1.000000      1.00000
# cell_markers_cd117                         1.000000      1.00000
# cell_markers_cd13                          0.000000      1.00000
# cell_markers_cd138                         1.000000      1.00000
# cell_markers_cd38                          0.000000      1.00000
# race_asian                                 0.000000      1.00000
# race_black_african_american                0.000000      1.00000
# race_other                                 0.000000      1.00000
# race_white                                 1.000000      1.00000

# %% [markdown]
# # Gene Expressions

# %%
genes.iloc[:8, :8]
# Out:
#           ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# ID
# MMRF1021              959                0             1264              668
# MMRF1024              776                0              972              595
# MMRF1029             1470                0             2143             1093
# MMRF1030               83                0             1235              422
# MMRF1031                2                0             1127              432
# MMRF1032               24                0              748              214
# MMRF1033               18                0              827              478
# MMRF1037               18                0              870              385
#
#           ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036
# ID
# MMRF1021              244               27             3711             1016
# MMRF1024               78              504               10             1263
# MMRF1029              209               36               20             3677
# MMRF1030               58               42               21             1714
# MMRF1031              190               48              117             2527
# MMRF1032               62               33               65              571
# MMRF1033               46              211                5              962
# MMRF1037               66               10               22             1165

# %% [markdown]
# # Treatments

# %%
treatments.head()
# Out:
#           therapy_first_line_Bor-Cyc-Dex  therapy_first_line_Bor-Dex  \
# ID
# MMRF1021                               0                           0
# MMRF1024                               0                           0
# MMRF1029                               0                           0
# MMRF1030                               0                           0
# MMRF1031                               0                           0
#
#           therapy_first_line_Bor-Len-Dex  therapy_first_line_Len-Dex  \
# ID
# MMRF1021                               1                           0
# MMRF1024                               0                           0
# MMRF1029                               1                           0
# MMRF1030                               1                           0
# MMRF1031                               1                           0
#
#           therapy_first_line_Non-therapy
# ID
# MMRF1021                               0
# MMRF1024                               1
# MMRF1029                               0
# MMRF1030                               0
# MMRF1031                               0

# %% [markdown]
# # THERAPY SENSITIVITY MODELLING

# %% [markdown]
# ## Cross-validation Experiment

# %%
from pipeline import MuLT

from sklearn.model_selection import StratifiedKFold
from evaluation import optimize_threshold, classification_metrics
from sklearn.metrics import roc_auc_score, log_loss, confusion_matrix


from constants import N_FOLDS, RANDOM_STATE
from util import join_values

import lightgbm as lgb
import pickle as pkl
import pandas as pd
import numpy as np
import time
import os

# creating analyser object to compute and group 
# classification matrics grouped by training and validation
# dataset and by experiment id
# analyser = Analyser()

# Creating 10-fold CV splits stratified by treatments and outcome
kfold = StratifiedKFold(N_FOLDS, shuffle=True, random_state=RANDOM_STATE)
split = kfold.split(np.zeros(outcome.shape[0]), join_values([treatments, outcome]))

#
#
result = {c: [] for c in ['experiment', 'train_auc', 'valid_auc', 
                          'train_loss', 'valid_loss', 'execution_time', 'threshold']}

for experiment, (train_index, valid_index) in enumerate(split):
    
    initial_time = time.time()
    
    print('{}\n\n'.format(experiment))
    
    #######################################################################################################
    # Split train & valid
    #######################################################################################################
    
    response_train = outcome.iloc[train_index, 0]
    response_valid = outcome.iloc[valid_index, 0]

    clinical_train = clinical.iloc[train_index, :]
    clinical_valid = clinical.iloc[valid_index, :]

    treatments_train = treatments.iloc[train_index, :]
    treatments_valid = treatments.iloc[valid_index, :]
    
    genes_train = genes.iloc[train_index, :]
    genes_valid = genes.iloc[valid_index, :]
    
    #######################################################################################################
    # Train & Test distances
    #######################################################################################################

    if False:
        
        dists = []

        for row_train in clinical.join(genes, how='inner').values:
            for row_valid in clinical.join(genes, how='inner').values:
                dists.append(np.linalg.norm(row_train-row_valid))

        train_test_distance_avg = np.mean(dists)
        train_test_distance_std = np.std(dists)
        train_test_distance_min = np.min(dists)
        train_test_distance_max = np.max(dists)

    #######################################################################################################
    # MuLT fitting
    #######################################################################################################
    
    mult = MuLT(experiment_number=experiment, 
                number_of_experiments=N_FOLDS, 
                output_path='./output/mult/', 
                random_state=RANDOM_STATE)

    mult.fit(clinical_train, genes_train, treatments_train, response_train, 

        lgb_fixed_parameters = {
            'metric': 'binary_logloss',
            'n_estimators': 100,
            'objective': 'binary',
            'is_unbalance': False, 
            'extra_trees': True,
            'max_depth': 4,
            'learning_rate': 0.1,
            'min_split_gain': 0.0001,
            'min_child_weight': 0.0001},

        optimization_n_call=50,
        optimization_n_folds=2,
        optimization_early_stopping_rounds=1,

        clinical_marker_selection_threshold=0.050,
        gene_selection_threshold=0.002,

        dae_decay_rate=1.0,
        dae_learning_rate=1e-1,
        dae_steps=100000,
        dae_early_stopping_rounds=1000,

        lgb_early_stopping_rounds=1,

        predictor_n_folds=3)

    with open('output/mult/trained_model_{}.pkl'.format(experiment), 'wb') as file:
        pkl.dump(mult, file)
    
    #######################################################################################################
    # MuLT inference
    #######################################################################################################

    y_hat_train = mult.predict(clinical_train, genes_train, treatments_train)
    y_hat_valid = mult.predict(clinical_valid, genes_valid, treatments_valid)

    #################################################################################################
    # Analysing Performance
    #################################################################################################   

    # Computing AUC
    train_auc = roc_auc_score(response_train, y_hat_train)
    valid_auc = roc_auc_score(response_valid, y_hat_valid)

    # Computing logLoss
    train_loss = log_loss(response_train, y_hat_train)
    valid_loss = log_loss(response_valid, y_hat_valid)

    # Compute optimized threshold
    opt_threshold = optimize_threshold(response_train, y_hat_train)

    if opt_threshold is None:
        opt_threshold = np.mean(response_train)

    # compute confusion matrix
    tn, fp, fn, tp = confusion_matrix(response_valid, [int(y >= opt_threshold) for y in y_hat_valid]).ravel()

    classification_results = classification_metrics(tn, fp, fn, tp)

    # add results to data frame (dict for now)
    for k in classification_results:
        if k not in result:
            result[k] = []
        result[k].append(classification_results[k])

    result['experiment'].append(experiment)
    result['train_auc'].append(train_auc)
    result['valid_auc'].append(valid_auc)
    result['train_loss'].append(train_loss)
    result['valid_loss'].append(valid_loss)
    result['execution_time'].append(time.time() - initial_time)
    result['threshold'].append(opt_threshold)

    print('Experiment {} with {} genes and {} clinical markers'.format(
          experiment, len(mult.selected_genes[0]), len(mult.selected_clinical[0])))

    print('Train: {}'.format(train_auc))

    print('Valid: {}'.format(valid_auc))

    print("\n========================================================================================\n")
    
    # Exporting inference
    response_train = pd.DataFrame(response_train)
    response_train['y_hat'] = y_hat_train
    response_train.to_csv('output/mult/inference/train_{}.csv'.format(experiment), index=True, sep=',')
    
    response_valid = pd.DataFrame(response_valid)
    response_valid['y_hat'] = y_hat_valid
    response_valid.to_csv('output/mult/inference/valid_{}.csv'.format(experiment), index=True, sep=',')
# Out:
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\correlation\pearson.py:21: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# Using TensorFlow backend.
# 0
#
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:82: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:83: The name tf.random.set_random_seed is deprecated. Please use tf.compat.v1.random.set_random_seed instead.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:86: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:94: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:98: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:104: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:120: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909D1D1D30>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909D1D1D30>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909D1D1D30>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909D1D1D30>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909D1D1D30>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909D1D1D30>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909D1D1D30>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909D1D1D30>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909CCC0278>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:149: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\base.py:91: The name tf.losses.mean_squared_error is deprecated. Please use tf.compat.v1.losses.mean_squared_error instead.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:488: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\base.py:58: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:498: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:216: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# early stopping after 1000 iterations without improvements with 1868 steps: best metric value 130.25230407714844
# WARNING:tensorflow:From C:\Users\Venezian\git\multiple-myeloma\model\dae.py:460: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.
#
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_000\graph\data_augmentation_adadelta_000
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_000\graph\data_augmentation_adadelta_000
# TRAIN mean log loss: 0.5039269686337223
# TRAIN mean AUC: 0.7181883079798558
# VALID mean log loss: 0.5162642554002138
# VALID mean AUC: 0.6778512881454059
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_000\graph\data_augmentation_adadelta_000
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_000\graph\data_augmentation_adadelta_000
# Experiment 0 with 16 genes and 6 clinical markers
# Train: 0.7124557260920897
# Valid: 0.7043610547667343
#
# ========================================================================================
#
# 1
#
#
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F12E10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F12E10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F12E10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F12E10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088EF5630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088EF5630>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088EF5630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088EF5630>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088EF5630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088EF5630>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088EF5630>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088EF5630>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F124E0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F124E0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F124E0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F124E0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F36B70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F36B70>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F36B70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F36B70>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F15C50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F15C50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F15C50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019088F15C50>>: AttributeError: module 'gast' has no attribute 'Index'
# early stopping after 1000 iterations without improvements with 2754 steps: best metric value 0.24007590115070343
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_001\graph\data_augmentation_adadelta_001
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_001\graph\data_augmentation_adadelta_001
# TRAIN mean log loss: 0.5163458190154637
# TRAIN mean AUC: 0.7204220048804242
# VALID mean log loss: 0.5302195926495847
# VALID mean AUC: 0.6104292965086727
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_001\graph\data_augmentation_adadelta_001
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_001\graph\data_augmentation_adadelta_001
# Experiment 1 with 9 genes and 6 clinical markers
# Train: 0.7430629244482172
# Valid: 0.7469990766389658
#
# ========================================================================================
#
# 2
#
#
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686F28>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686C18>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686C18>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686C18>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686C18>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686C18>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686C18>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686C18>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686C18>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686EB8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686EB8>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686EB8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086686EB8>>: AttributeError: module 'gast' has no attribute 'Index'
# early stopping after 1000 iterations without improvements with 1133 steps: best metric value 85.6384048461914
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_002\graph\data_augmentation_adadelta_002
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_002\graph\data_augmentation_adadelta_002
# TRAIN mean log loss: 0.48928459650550926
# TRAIN mean AUC: 0.8042939792468672
# VALID mean log loss: 0.5150002733537947
# VALID mean AUC: 0.6914346441022556
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_002\graph\data_augmentation_adadelta_002
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_002\graph\data_augmentation_adadelta_002
# Experiment 2 with 23 genes and 5 clinical markers
# Train: 0.7970142720713074
# Valid: 0.6325023084025854
#
# ========================================================================================
#
# 3
#
#
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085EC8160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085EC8160>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085EC8160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085EC8160>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F13160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F13160>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F13160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F13160>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F13160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F13160>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F13160>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F13160>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F53B00>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F53B00>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F53B00>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F53B00>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F53B00>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F53B00>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F53B00>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F53B00>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F06198>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F06198>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F06198>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085F06198>>: AttributeError: module 'gast' has no attribute 'Index'
# early stopping after 1000 iterations without improvements with 2604 steps: best metric value 1.7429368495941162
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_003\graph\data_augmentation_adadelta_003
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_003\graph\data_augmentation_adadelta_003
# TRAIN mean log loss: 0.507589013609389
# TRAIN mean AUC: 0.7421109858544419
# VALID mean log loss: 0.5277159823689411
# VALID mean AUC: 0.6222886793758516
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_003\graph\data_augmentation_adadelta_003
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_003\graph\data_augmentation_adadelta_003
# Experiment 3 with 8 genes and 7 clinical markers
# Train: 0.7433752843860549
# Valid: 0.7271825396825397
#
# ========================================================================================
#
# 4
#
#
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190869A5940>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190869A5940>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190869A5940>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190869A5940>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190869A5940>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190869A5940>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190869A5940>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190869A5940>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085686860>>: AttributeError: module 'gast' has no attribute 'Index'
# early stopping after 1000 iterations without improvements with 1827 steps: best metric value 2059.819580078125
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_004\graph\data_augmentation_adadelta_004
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_004\graph\data_augmentation_adadelta_004
# TRAIN mean log loss: 0.4847276047784986
# TRAIN mean AUC: 0.8127510040160644
# VALID mean log loss: 0.5226714410241641
# VALID mean AUC: 0.652846680841011
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_004\graph\data_augmentation_adadelta_004
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_004\graph\data_augmentation_adadelta_004
# Experiment 4 with 32 genes and 7 clinical markers
# Train: 0.809433813686117
# Valid: 0.594949494949495
#
# ========================================================================================
#
# 5
#
#
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190866489E8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190866489E8>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190866489E8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x00000190866489E8>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908840A0F0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908840A0F0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908840A0F0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908840A0F0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648860>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648860>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648860>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648780>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648780>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648780>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648780>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648780>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648C50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648C50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648C50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019086648C50>>: AttributeError: module 'gast' has no attribute 'Index'
# early stopping after 1000 iterations without improvements with 1500 steps: best metric value 0.03933369368314743
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_005\graph\data_augmentation_adadelta_005
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_005\graph\data_augmentation_adadelta_005
# TRAIN mean log loss: 0.5165597265630361
# TRAIN mean AUC: 0.6838221437052225
# VALID mean log loss: 0.5238283732572341
# VALID mean AUC: 0.6412327288036005
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_005\graph\data_augmentation_adadelta_005
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_005\graph\data_augmentation_adadelta_005
# Experiment 5 with 5 genes and 7 clinical markers
# Train: 0.6906326605121786
# Valid: 0.6973262032085561
#
# ========================================================================================
#
# 6
#
#
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FFD06A0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FFD06A0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FFD06A0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FFD06A0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FFD06A0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FFD06A0>>: AttributeError: module 'gast' has no attribute 'Index'
# ...
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085673550>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085673550>>: AttributeError: module 'gast' has no attribute 'Index'
# early stopping after 1000 iterations without improvements with 1034 steps: best metric value 40.00886535644531
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_007\graph\data_augmentation_adadelta_007
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_007\graph\data_augmentation_adadelta_007
# TRAIN mean log loss: 0.5154661841527436
# TRAIN mean AUC: 0.7026785966921508
# VALID mean log loss: 0.5250981164381051
# VALID mean AUC: 0.6438346661635025
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_007\graph\data_augmentation_adadelta_007
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_007\graph\data_augmentation_adadelta_007
# Experiment 7 with 18 genes and 8 clinical markers
# Train: 0.712611119675248
# Valid: 0.675925925925926
#
# ========================================================================================
#
# 8
#
#
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909E351E48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909E351E48>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909E351E48>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909E351E48>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FFD09E8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FFD09E8>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FFD09E8>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FFD09E8>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001909FF89E10>>: AttributeError: module 'gast' has no attribute 'Index'
# early stopping after 1000 iterations without improvements with 2876 steps: best metric value 78.81928253173828
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_008\graph\data_augmentation_adadelta_008
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_008\graph\data_augmentation_adadelta_008
# TRAIN mean log loss: 0.4967629980449087
# TRAIN mean AUC: 0.7796822198403395
# VALID mean log loss: 0.5187023062449295
# VALID mean AUC: 0.6944229215885406
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_008\graph\data_augmentation_adadelta_008
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_008\graph\data_augmentation_adadelta_008
# Experiment 8 with 23 genes and 7 clinical markers
# Train: 0.7724735184655024
# Valid: 0.6742919389978215
#
# ========================================================================================
#
# 9
#
#
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974A8D0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974A8D0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974A8D0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974A8D0>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908A256E80>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908A256E80>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908A256E80>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908A256E80>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019089D43F98>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019089D43F98>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019089D43F98>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019089D43F98>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974AB70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974AB70>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974AB70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974AB70>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974AB70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974AB70>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974AB70>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x000001908974AB70>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085EDC358>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085EDC358>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085EDC358>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x0000019085EDC358>>: AttributeError: module 'gast' has no attribute 'Index'
# early stopping after 1000 iterations without improvements with 1921 steps: best metric value 108.95012664794922
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_009\graph\data_augmentation_adadelta_009
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_009\graph\data_augmentation_adadelta_009
# TRAIN mean log loss: 0.4957697369237293
# TRAIN mean AUC: 0.7572953909031753
# VALID mean log loss: 0.51804846899994
# VALID mean AUC: 0.6824964005226123
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_009\graph\data_augmentation_adadelta_009
# INFO:tensorflow:Restoring parameters from C:\Users\Venezian\git\multiple-myeloma\output\mult\dae\data_augmentation_adadelta_009\graph\data_augmentation_adadelta_009
# Experiment 9 with 23 genes and 7 clinical markers
# Train: 0.7533658797055571
# Valid: 0.679945054945055
#
# ========================================================================================

# %%
result = pd.DataFrame(result)

result.to_csv('output/mult/metrics.csv', sep=',', index=False)

result
# Out:
#    experiment  train_auc  valid_auc  train_loss  valid_loss  execution_time  \
# 0           0   0.712456   0.704361    0.772127    0.639063      139.014572
# 1           1   0.743063   0.746999    0.502551    0.503089      194.791050
# 2           2   0.797014   0.632502    0.441184    0.626764      216.077752
# 3           3   0.743375   0.727183    0.520552    0.550897      142.785776
# 4           4   0.809434   0.594949    0.470249    0.609937      137.610523
# 5           5   0.690633   0.697326    1.977342    2.473817      226.927069
# 6           6   0.778399   0.733690    0.525325    0.536358      115.080250
# 7           7   0.712611   0.675926    0.730144    1.239241      259.405892
# 8           8   0.772474   0.674292    0.508688    0.603379      134.721194
# 9           9   0.753366   0.679945    0.577517    0.640395      441.330027
#
#    threshold  accuracy  precision  sensitivity  specificity
# 0   0.482681  0.706667   0.352941     0.352941     0.810345
# 1   0.200000  0.618421   0.380952     0.842105     0.543860
# 2   0.294788  0.578947   0.303030     0.526316     0.596491
# 3   0.452093  0.729730   0.458333     0.611111     0.767857
# 4   0.330000  0.561644   0.294118     0.555556     0.563636
# 5   0.350000  0.694444   0.391304     0.529412     0.745455
# 6   0.441281  0.694444   0.400000     0.588235     0.727273
# 7   0.310000  0.565217   0.325581     0.933333     0.462963
# 8   0.391122  0.690141   0.400000     0.588235     0.722222
# 9   0.380817  0.621212   0.310345     0.642857     0.615385

# %%
result.mean()
# Out:
# experiment          4.500000
# train_auc           0.751282
# valid_auc           0.686717
# train_loss          0.702568
# valid_loss          0.842294
# execution_time    200.774410
# threshold           0.363278
# accuracy            0.646087
# precision           0.361661
# sensitivity         0.617010
# specificity         0.655549
# dtype: float64

# %%
result.std()
# Out:
# experiment         3.027650
# train_auc          0.038691
# valid_auc          0.046642
# train_loss         0.460763
# valid_loss         0.610336
# execution_time    97.257826
# threshold          0.084843
# accuracy           0.063984
# precision          0.053278
# sensitivity        0.164146
# specificity        0.114193
# dtype: float64

# %% [markdown]
# ## Analyse per Treatments

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

def classification_metrics(x):
    try:
        
        tn, fp, fn, tp = confusion_matrix(x['y_true'], x['y_hat_hard']).ravel()
        
        sensitivity, specificity = tp / (tp + fn), tn / (tn + fp)
        
        precision = tp / (tp + fp)
        
        return pd.Series({
            'AUC': roc_auc_score(x['y_true'], x['y_hat_adjusted']),
            'Accuracy': accuracy_score(x['y_true'], x['y_hat_hard']),
            'Sensitivity': sensitivity,
            'Specificity': specificity,
            'Precision': precision,
            'F1': 2 * precision * sensitivity / (precision + sensitivity)})
    
    except:
        return pd.Series({
            'AUC': 0.0,
            'Accuracy': 0.0,
            'Sensitivity': 0.0,
            'Specificity': 0.0,
            'Precision': 0.0,
            'F1': 0.0})
    
BASE_DIR = 'output/mult/inference/'
    
df = None

metrics = pd.read_csv('output/mult/metrics.csv', sep=',')

for file in os.listdir(BASE_DIR):
    if 'valid' in file:
        index = file.split('_')[1].split('.')[0]
        train = pd.read_csv(os.path.join(BASE_DIR, 'train_{}.csv'.format(index)), sep=',')
        t = metrics[metrics['experiment'] == int(index)]['threshold'].values[0]
        tmp = pd.read_csv(os.path.join(BASE_DIR, file), sep=',')
        df = tmp if df is None else pd.concat([df, tmp], axis=0)
        df['y_hat_hard'] = df['y_hat'].apply(lambda x: 1 if x >= t else 0)
        
df = df.set_index('ID', drop=True)

df = df.join(treatments[treatments==1].stack().reset_index().drop(0,1).set_index('ID').rename(
    columns={'level_1': 'treatments'}))

df = df.rename(columns={'response_best_response_first_line': 'y_true'})

df.groupby('treatments').apply(classification_metrics)
# Out:
#                                 AUC  Accuracy  Sensitivity  Specificity  \
# treatments
# therapy_first_line_Bor-Cyc-Dex  0.0       0.0          0.0          0.0
# therapy_first_line_Bor-Dex      0.0       0.0          0.0          0.0
# therapy_first_line_Bor-Len-Dex  0.0       0.0          0.0          0.0
# therapy_first_line_Len-Dex      0.0       0.0          0.0          0.0
# therapy_first_line_Non-therapy  0.0       0.0          0.0          0.0
#
#                                 Precision   F1
# treatments
# therapy_first_line_Bor-Cyc-Dex        0.0  0.0
# therapy_first_line_Bor-Dex            0.0  0.0
# therapy_first_line_Bor-Len-Dex        0.0  0.0
# therapy_first_line_Len-Dex            0.0  0.0
# therapy_first_line_Non-therapy        0.0  0.0
