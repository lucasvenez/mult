# %% [markdown]
# # Loading Clinical Data

# %%
from data import load_data

clinical, _, _, treatments, outcome = load_data()

clinical.head()
# Out:
#           cmmc  ecog_ps  percent_aneuploid  percent_plama_cells_bone_marrow  \
# ID
# MMRF1021   NaN      1.0                0.0                              4.9
# MMRF1024   NaN      1.0               11.0                              6.0
# MMRF1029   NaN      1.0                0.0                              8.4
# MMRF1030   NaN      1.0               15.4                              9.6
# MMRF1031   NaN      NaN               18.3                             10.1
#
#           percent_plama_cells_peripherical_blood  creatinine  iss  \
# ID
# MMRF1021                                     0.0      88.400  1.0
# MMRF1024                                     0.0     123.760  2.0
# MMRF1029                                     0.0     106.080  1.0
# MMRF1030                                     0.0      55.692  1.0
# MMRF1031                                     0.0      81.328  1.0
#
#           absolute_neutrophil  platelet  wbc_x10_10_9_l  ...  m_protein  \
# ID                                                       ...
# MMRF1021                 2.40     216.0             5.2  ...       3.05
# MMRF1024                 2.30     188.0             4.3  ...       2.60
# MMRF1029                 2.60     219.0             4.0  ...       1.80
# MMRF1030                 2.50     215.0             4.7  ...       3.55
# MMRF1031                10.29     385.0            12.4  ...       1.52
#
#           first_line_transplant  cell_markers_cd117  cell_markers_cd13  \
# ID
# MMRF1021                      1                   0                  1
# MMRF1024                      0                   1                  0
# MMRF1029                      0                   1                  0
# MMRF1030                      1                   1                  0
# MMRF1031                      0                   1                  0
#
#           cell_markers_cd138  cell_markers_cd38  race_asian  \
# ID
# MMRF1021                   0                  0           0
# MMRF1024                   0                  0           0
# MMRF1029                   0                  0           0
# MMRF1030                   0                  0           0
# MMRF1031                   0                  0           0
#
#           race_black_african_american  race_other  race_white
# ID
# MMRF1021                            0           0           1
# MMRF1024                            0           0           1
# MMRF1029                            0           0           1
# MMRF1030                            0           0           1
# MMRF1031                            0           0           1
#
# [5 rows x 35 columns]

# %%
for c in clinical.columns:
    print(c, clinical[c].dtype)
# Out:
# cmmc float64
# ecog_ps float64
# percent_aneuploid float64
# percent_plama_cells_bone_marrow float64
# percent_plama_cells_peripherical_blood float64
# creatinine float64
# iss float64
# absolute_neutrophil float64
# platelet float64
# wbc_x10_10_9_l float64
# bun float64
# glucose float64
# total_protein float64
# albumin float64
# beta_2_microglobulin float64
# calcium float64
# hemoglobin float64
# ldh float64
# age float64
# gender int64
# lga float64
# lgg float64
# lgl_kappa float64
# lgl_lambda float64
# lgm float64
# m_protein float64
# first_line_transplant int64
# cell_markers_cd117 uint8
# cell_markers_cd13 uint8
# cell_markers_cd138 uint8
# cell_markers_cd38 uint8
# race_asian uint8
# race_black_african_american uint8
# race_other uint8
# race_white uint8

# %%
from evaluation import optimize_threshold, classification_metrics
from constants import N_FOLDS, RANDOM_STATE

from sklearn.metrics import roc_auc_score, log_loss, confusion_matrix
from sklearn.model_selection import StratifiedKFold

from optimization import LightGBMOptimizer

from lightgbm import LGBMModel

import pandas as pd
import pickle
import time
import os

result = {c: [] for c in ['experiment', 'marker', 'train_auc', 'valid_auc', 
                          'train_loss', 'valid_loss', 'execution_time', 'threshold']}

for t in clinical.columns:
    
    print('*********************************************************************************')
    print(t)
    print('*********************************************************************************\n')
    
    y = outcome.dropna()
    
    x = clinical[[t]].dropna().join(treatments, how='inner')
    
    x = x.join(y)[x.columns]
    y = x.join(y)[y.columns[0]]
    
    opt_kf = StratifiedKFold(N_FOLDS, shuffle=True, random_state=RANDOM_STATE)
    
    if y.sum() < 10 or (1 - y).sum() < 10:
        print('Ignoring {} marker once it has less than five treatment senstive patients associted.')
    
    for experiment, (opt_train, opt_valid) in enumerate(opt_kf.split(x, y)):
        
        initial_time = time.time()
        
        #################################################################################################
        # Train and Valid Split
        #################################################################################################
        
        x_train, y_train = x.iloc[opt_train,:], y.iloc[opt_train]
        
        x_valid, y_valid = x.iloc[opt_valid,:], y.iloc[opt_valid]
        
        #################################################################################################
        # Hyper parameters optimization
        #################################################################################################        
        
        training_default_params = {
            'objective': 'binary',
            'metric': 'binary_logloss',
            'n_estimators': 100,
            'objective': 'binary',
            'is_unbalance': False, 
            'extra_trees': True,
            'max_depth': 4,
            'learning_rate': 0.1,
            'min_split_gain': 0.0001,
            'min_child_weight': 0.0001,
            'random_state': RANDOM_STATE}
        
        optimizer_params = {
            'n_folds': 2, 
            'n_calls': 50, 
            'shuffle': True, 
            'early_stopping_rounds': 1,
            'fixed_parameters': training_default_params, 
            'random_state': RANDOM_STATE, 
            'use_gpu': False}
        
        optimizer = LightGBMOptimizer(**optimizer_params)
        
        params = optimizer.optimize(x_train, y_train)

        params = {**params, **training_default_params}
        
        skf = StratifiedKFold(3, shuffle=True, random_state=RANDOM_STATE)

        models = []
        
        for train_index, valid_index in skf.split(x_train, y_train):

            xx_train, yy_train = x_train.values[train_index, :], y_train.values[train_index]
            xx_valid, yy_valid = x_train.values[valid_index, :], y_train.values[valid_index]

            gbm = LGBMModel(**params)

            gbm.fit(xx_train, 
                    yy_train,
                    eval_set=[(xx_valid, yy_valid)],
                    early_stopping_rounds=1,
                    verbose=False)
            
            models.append(gbm)
        
        #################################################################################################
        # Predicting
        #################################################################################################        
        
        y_hat_train, y_hat_valid = None, None
        
        for model in models:
            
            y_ = model.predict(x_train)
            y_hat_train = y_ if y_hat_train is None else y_ + y_hat_train
            
            y_ = model.predict(x_valid)
            y_hat_valid = y_ if y_hat_valid is None else y_ + y_hat_valid
        
        y_hat_train /= len(models)
        y_hat_valid /= len(models)
        
        #################################################################################################
        # Analysing Performance
        #################################################################################################   
        
        # Computing AUC
        train_auc = roc_auc_score(y_train, y_hat_train)
        valid_auc = roc_auc_score(y_valid, y_hat_valid)
        
        # Computing logLoss
        train_loss = log_loss(y_train, y_hat_train)
        valid_loss = log_loss(y_valid, y_hat_valid)
        
        # Compute optimized threshold
        opt_threshold = optimize_threshold(y_train, y_hat_train)

        if opt_threshold is None:
            opt_threshold = np.mean(y_train)
        
        # compute confusion matrix
        tn, fp, fn, tp = confusion_matrix(y_valid, [int(y >= opt_threshold) for y in y_]).ravel()

        classification_results = classification_metrics(tn, fp, fn, tp)
        
        # add results to data frame (dict for now)
        for k in classification_results:
            if k not in result:
                result[k] = []
            result[k].append(classification_results[k])
        
        result['experiment'].append(experiment)
        result['marker'].append(t)
        result['train_auc'].append(train_auc)
        result['valid_auc'].append(valid_auc)
        result['train_loss'].append(train_loss)
        result['valid_loss'].append(valid_loss)
        result['execution_time'].append(time.time() - initial_time)
        result['threshold'].append(opt_threshold)
        
        log_message = 'Experiment #{}: '.format(experiment) + 'Train AUC: {}'.format(train_auc) + ' '
        log_message += 'Valid AUC: {}'.format(valid_auc)
        
        print(log_message)
    
    print('')
   
result = pd.DataFrame(result)

result.to_csv('output/gene/metrics_clinical_only.csv', sep=',', index=False)

result.head()
# Out:
# *********************************************************************************
# cmmc
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6251167133520075 Valid AUC: 0.5120689655172413
# Experiment #1: Train AUC: 0.6421994884910486 Valid AUC: 0.5428571428571428
# Experiment #2: Train AUC: 0.6238084166472914 Valid AUC: 0.45000000000000007
# Experiment #3: Train AUC: 0.6488723552662172 Valid AUC: 0.4696428571428572
# Experiment #4: Train AUC: 0.6125784701232271 Valid AUC: 0.842857142857143
# Experiment #5: Train AUC: 0.6491865061126942 Valid AUC: 0.4742063492063493
# Experiment #6: Train AUC: 0.6221849434690688 Valid AUC: 0.75
# Experiment #7: Train AUC: 0.6453028771026749 Valid AUC: 0.6924603174603174
# Experiment #8: Train AUC: 0.6552992002941447 Valid AUC: 0.40674603174603174
# Experiment #9: Train AUC: 0.608534791800717 Valid AUC: 0.6587301587301588
#
# *********************************************************************************
# ecog_ps
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6059794734493531 Valid AUC: 0.4575892857142857
# Experiment #1: Train AUC: 0.576723560910308 Valid AUC: 0.5892857142857143
# Experiment #2: Train AUC: 0.6173304328424811 Valid AUC: 0.3839285714285714
# Experiment #3: Train AUC: 0.6025769745649264 Valid AUC: 0.5334821428571429
# Experiment #4: Train AUC: 0.5858712628290943 Valid AUC: 0.6116071428571429
# Experiment #5: Train AUC: 0.5939033913431504 Valid AUC: 0.5959821428571428
# Experiment #6: Train AUC: 0.5965528781793842 Valid AUC: 0.5892857142857142
# Experiment #7: Train AUC: 0.6030555555555557 Valid AUC: 0.525462962962963
# Experiment #8: Train AUC: 0.5972222222222222 Valid AUC: 0.5601851851851852
# Experiment #9: Train AUC: 0.6094444444444445 Valid AUC: 0.4699074074074074
#
# *********************************************************************************
# percent_aneuploid
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6613531383026899 Valid AUC: 0.7116724738675958
# Experiment #1: Train AUC: 0.6724934335658002 Valid AUC: 0.6184668989547039
# Experiment #2: Train AUC: 0.6651118558101621 Valid AUC: 0.5670731707317073
# Experiment #3: Train AUC: 0.6514812807659305 Valid AUC: 0.7455357142857143
# Experiment #4: Train AUC: 0.6532425597254211 Valid AUC: 0.6276785714285714
# Experiment #5: Train AUC: 0.6633134624937903 Valid AUC: 0.6866071428571429
# Experiment #6: Train AUC: 0.6732513606127797 Valid AUC: 0.6057692307692307
# Experiment #7: Train AUC: 0.6713924164035029 Valid AUC: 0.5682692307692307
# Experiment #8: Train AUC: 0.6571815718157182 Valid AUC: 0.7067307692307693
# Experiment #9: Train AUC: 0.6406638446549755 Valid AUC: 0.6115384615384616
#
# *********************************************************************************
# percent_plama_cells_bone_marrow
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6241471215351813 Valid AUC: 0.42978723404255315
# Experiment #1: Train AUC: 0.5839818763326227 Valid AUC: 0.5758865248226951
# Experiment #2: Train AUC: 0.5903518123667377 Valid AUC: 0.6404255319148936
# Experiment #3: Train AUC: 0.6000621890547263 Valid AUC: 0.6638297872340425
# Experiment #4: Train AUC: 0.6371446339729923 Valid AUC: 0.48865248226950353
# Experiment #5: Train AUC: 0.6039090262970859 Valid AUC: 0.6198581560283688
# Experiment #6: Train AUC: 0.6035714285714286 Valid AUC: 0.6333333333333333
# Experiment #7: Train AUC: 0.5971390080476476 Valid AUC: 0.6666666666666666
# Experiment #8: Train AUC: 0.607446733080441 Valid AUC: 0.5978260869565218
# Experiment #9: Train AUC: 0.6027799771267704 Valid AUC: 0.65527950310559
#
# *********************************************************************************
# percent_plama_cells_peripherical_blood
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6627132196162047 Valid AUC: 0.4971631205673759
# Experiment #1: Train AUC: 0.6493958777540867 Valid AUC: 0.6446808510638298
# Experiment #2: Train AUC: 0.5903518123667377 Valid AUC: 0.6404255319148936
# Experiment #3: Train AUC: 0.6475035536602701 Valid AUC: 0.6695035460992909
# Experiment #4: Train AUC: 0.655001776830135 Valid AUC: 0.5524822695035461
# Experiment #5: Train AUC: 0.6354388770433547 Valid AUC: 0.6524822695035462
# Experiment #6: Train AUC: 0.6402629708599857 Valid AUC: 0.6943262411347517
# Experiment #7: Train AUC: 0.6530116637714043 Valid AUC: 0.5927536231884057
# Experiment #8: Train AUC: 0.6642411458148687 Valid AUC: 0.5608695652173913
# Experiment #9: Train AUC: 0.6296384270256004 Valid AUC: 0.7453416149068323
#
# *********************************************************************************
# creatinine
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6138523391812866 Valid AUC: 0.49518716577540106
# Experiment #1: Train AUC: 0.606006160164271 Valid AUC: 0.5751633986928104
# Experiment #2: Train AUC: 0.6099778450232357 Valid AUC: 0.5190631808278866
# Experiment #3: Train AUC: 0.5982519182967686 Valid AUC: 0.6230936819172113
# Experiment #4: Train AUC: 0.6002242515940776 Valid AUC: 0.5588235294117647
# Experiment #5: Train AUC: 0.574144871933427 Valid AUC: 0.5566448801742919
# Experiment #6: Train AUC: 0.6236355776504917 Valid AUC: 0.4379084967320262
# Experiment #7: Train AUC: 0.5634051118556144 Valid AUC: 0.6465141612200436
# Experiment #8: Train AUC: 0.5742867178212472 Valid AUC: 0.5533769063180828
# Experiment #9: Train AUC: 0.5788339976647742 Valid AUC: 0.677662037037037
#
# *********************************************************************************
# iss
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5865493443754313 Valid AUC: 0.4738562091503268
# Experiment #1: Train AUC: 0.5752518978605935 Valid AUC: 0.5490196078431373
# Experiment #2: Train AUC: 0.5839406487232575 Valid AUC: 0.46786492374727673
# Experiment #3: Train AUC: 0.5985645272601794 Valid AUC: 0.5217864923747277
# Experiment #4: Train AUC: 0.5821601104209799 Valid AUC: 0.5784313725490197
# Experiment #5: Train AUC: 0.5834368530020704 Valid AUC: 0.45806100217864926
# Experiment #6: Train AUC: 0.559144237405107 Valid AUC: 0.5354030501089324
# Experiment #7: Train AUC: 0.5745990914564064 Valid AUC: 0.5795990566037735
# Experiment #8: Train AUC: 0.571493076459964 Valid AUC: 0.6043632075471698
# Experiment #9: Train AUC: 0.5709457610420885 Valid AUC: 0.6120283018867925
#
# *********************************************************************************
# absolute_neutrophil
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.568045267489712 Valid AUC: 0.5800653594771241
# Experiment #1: Train AUC: 0.5800548696844994 Valid AUC: 0.5354030501089324
# Experiment #2: Train AUC: 0.641323731138546 Valid AUC: 0.3856209150326797
# Experiment #3: Train AUC: 0.5793072702331962 Valid AUC: 0.5163398692810458
# Experiment #4: Train AUC: 0.6069478737997256 Valid AUC: 0.5729847494553376
# Experiment #5: Train AUC: 0.5879629629629629 Valid AUC: 0.42047930283224405
# Experiment #6: Train AUC: 0.5781618655692731 Valid AUC: 0.5473856209150326
# Experiment #7: Train AUC: 0.5644945902488213 Valid AUC: 0.670138888888889
# Experiment #8: Train AUC: 0.5766494971792985 Valid AUC: 0.5694444444444444
# Experiment #9: Train AUC: 0.5699520344479874 Valid AUC: 0.6174768518518519
#
# *********************************************************************************
# platelet
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5875171305081173 Valid AUC: 0.5381944444444444
# Experiment #1: Train AUC: 0.6089036971093422 Valid AUC: 0.3671218487394958
# Experiment #2: Train AUC: 0.5679074446680081 Valid AUC: 0.5502673796791444
# Experiment #3: Train AUC: 0.5631059081763308 Valid AUC: 0.6679144385026738
# Experiment #4: Train AUC: 0.5711672633201808 Valid AUC: 0.6229946524064172
# Experiment #5: Train AUC: 0.5771838825158745 Valid AUC: 0.5679144385026738
# Experiment #6: Train AUC: 0.593633227939063 Valid AUC: 0.388235294117647
# Experiment #7: Train AUC: 0.5773276019754893 Valid AUC: 0.5647058823529412
# Experiment #8: Train AUC: 0.5760733230552144 Valid AUC: 0.5759358288770053
# Experiment #9: Train AUC: 0.5729049622409784 Valid AUC: 0.6053475935828877
#
# *********************************************************************************
# wbc_x10_10_9_l
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6509328358208956 Valid AUC: 0.45602836879432623
# Experiment #1: Train AUC: 0.5782871357498224 Valid AUC: 0.5780141843971631
# Experiment #2: Train AUC: 0.5897832267235251 Valid AUC: 0.6375886524822696
# Experiment #3: Train AUC: 0.6303837953091684 Valid AUC: 0.6971631205673758
# Experiment #4: Train AUC: 0.6189943141435679 Valid AUC: 0.47801418439716314
# Experiment #5: Train AUC: 0.6041222459132907 Valid AUC: 0.6163120567375886
# Experiment #6: Train AUC: 0.6028251599147121 Valid AUC: 0.6333333333333333
# Experiment #7: Train AUC: 0.5997358811642499 Valid AUC: 0.6572463768115943
# Experiment #8: Train AUC: 0.6064895238770518 Valid AUC: 0.6007246376811595
# Experiment #9: Train AUC: 0.5978446379871558 Valid AUC: 0.6801242236024845
#
# *********************************************************************************
# bun
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6529982363315696 Valid AUC: 0.6275510204081632
# Experiment #1: Train AUC: 0.6325690770135215 Valid AUC: 0.5391156462585034
# Experiment #2: Train AUC: 0.6305219618711682 Valid AUC: 0.560374149659864
# Experiment #3: Train AUC: 0.6234987822289411 Valid AUC: 0.6215986394557823
# Experiment #4: Train AUC: 0.6608927521625935 Valid AUC: 0.4897959183673469
# Experiment #5: Train AUC: 0.6657428403460149 Valid AUC: 0.5620748299319728
# Experiment #6: Train AUC: 0.6146804400772654 Valid AUC: 0.6930272108843538
# Experiment #7: Train AUC: 0.6541005291005291 Valid AUC: 0.5850340136054422
# Experiment #8: Train AUC: 0.6453241790543377 Valid AUC: 0.6326530612244898
# Experiment #9: Train AUC: 0.639644746787604 Valid AUC: 0.7865646258503401
#
# *********************************************************************************
# glucose
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5597841154834298 Valid AUC: 0.6123188405797102
# Experiment #1: Train AUC: 0.6372474724137294 Valid AUC: 0.5528985507246378
# Experiment #2: Train AUC: 0.6042640888675304 Valid AUC: 0.6630434782608696
# Experiment #3: Train AUC: 0.6069626453246585 Valid AUC: 0.6340579710144928
# Experiment #4: Train AUC: 0.6146239580060255 Valid AUC: 0.5688405797101449
# Experiment #5: Train AUC: 0.620363011293274 Valid AUC: 0.5630434782608695
# Experiment #6: Train AUC: 0.6265316604299657 Valid AUC: 0.6847826086956522
# Experiment #7: Train AUC: 0.6103529239122458 Valid AUC: 0.6001552795031055
# Experiment #8: Train AUC: 0.6316952821190109 Valid AUC: 0.5690993788819876
# Experiment #9: Train AUC: 0.6124194847020934 Valid AUC: 0.5817460317460317
#
# *********************************************************************************
# total_protein
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6117936117936118 Valid AUC: 0.555072463768116
# Experiment #1: Train AUC: 0.6232875437420892 Valid AUC: 0.5231884057971015
# Experiment #2: Train AUC: 0.6277827414191051 Valid AUC: 0.5413043478260869
# Experiment #3: Train AUC: 0.6006758764111705 Valid AUC: 0.5592592592592592
# Experiment #4: Train AUC: 0.6198102346999406 Valid AUC: 0.5274074074074073
# Experiment #5: Train AUC: 0.611575311942959 Valid AUC: 0.5540740740740742
# Experiment #6: Train AUC: 0.5928494503862152 Valid AUC: 0.7103703703703704
# Experiment #7: Train AUC: 0.6062306501547987 Valid AUC: 0.6031746031746033
# Experiment #8: Train AUC: 0.6019368273625239 Valid AUC: 0.638095238095238
# Experiment #9: Train AUC: 0.5984077841662981 Valid AUC: 0.7325396825396826
#
# *********************************************************************************
# albumin
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6130696416497634 Valid AUC: 0.5834224598930482
# Experiment #1: Train AUC: 0.5766666666666667 Valid AUC: 0.5898395721925134
# Experiment #2: Train AUC: 0.6609871534820826 Valid AUC: 0.5363636363636365
# Experiment #3: Train AUC: 0.6514131169709263 Valid AUC: 0.5877005347593582
# Experiment #4: Train AUC: 0.5967680865449628 Valid AUC: 0.6572192513368984
# Experiment #5: Train AUC: 0.5775929682217714 Valid AUC: 0.5770053475935829
# Experiment #6: Train AUC: 0.6564976335361731 Valid AUC: 0.5406417112299465
# Experiment #7: Train AUC: 0.5710610802896176 Valid AUC: 0.6079545454545455
# Experiment #8: Train AUC: 0.5849733222511193 Valid AUC: 0.49074074074074076
# Experiment #9: Train AUC: 0.604123656058128 Valid AUC: 0.6284722222222222
#
# *********************************************************************************
# beta_2_microglobulin
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6368658195908803 Valid AUC: 0.579483695652174
# Experiment #1: Train AUC: 0.6149008873622442 Valid AUC: 0.6601449275362319
# Experiment #2: Train AUC: 0.5839952769428939 Valid AUC: 0.5898550724637681
# Experiment #3: Train AUC: 0.6300450837269215 Valid AUC: 0.48768115942028983
# Experiment #4: Train AUC: 0.6420674109059682 Valid AUC: 0.6275362318840582
# Experiment #5: Train AUC: 0.6366108487190497 Valid AUC: 0.5855072463768116
# Experiment #6: Train AUC: 0.5850418634607127 Valid AUC: 0.5847826086956521
# Experiment #7: Train AUC: 0.6544474585950886 Valid AUC: 0.5096296296296297
# Experiment #8: Train AUC: 0.6632727727013136 Valid AUC: 0.5548148148148148
# Experiment #9: Train AUC: 0.6364755853797829 Valid AUC: 0.5962962962962963
#
# *********************************************************************************
# calcium
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6063462772785623 Valid AUC: 0.3775401069518717
# Experiment #1: Train AUC: 0.5964243688489517 Valid AUC: 0.5422459893048128
# Experiment #2: Train AUC: 0.592479674796748 Valid AUC: 0.5080213903743316
# Experiment #3: Train AUC: 0.56899203038083 Valid AUC: 0.6058823529411764
# Experiment #4: Train AUC: 0.5689586007702182 Valid AUC: 0.639572192513369
# Experiment #5: Train AUC: 0.5825577663671373 Valid AUC: 0.49197860962566853
# Experiment #6: Train AUC: 0.575885216089003 Valid AUC: 0.5636363636363637
# Experiment #7: Train AUC: 0.5637544037578734 Valid AUC: 0.64760348583878
# Experiment #8: Train AUC: 0.5748839009287925 Valid AUC: 0.5702614379084967
# Experiment #9: Train AUC: 0.5584987206512084 Valid AUC: 0.6302083333333334
#
# *********************************************************************************
# hemoglobin
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6459344301100722 Valid AUC: 0.5009920634920636
# Experiment #1: Train AUC: 0.6535642425984479 Valid AUC: 0.39338235294117646
# Experiment #2: Train AUC: 0.6425697039379132 Valid AUC: 0.5814075630252101
# Experiment #3: Train AUC: 0.6184478172429981 Valid AUC: 0.6288770053475935
# Experiment #4: Train AUC: 0.6105265216711 Valid AUC: 0.6363636363636364
# Experiment #5: Train AUC: 0.6244262765347104 Valid AUC: 0.6636363636363637
# Experiment #6: Train AUC: 0.6422117039586919 Valid AUC: 0.5042780748663102
# Experiment #7: Train AUC: 0.6157813070463674 Valid AUC: 0.6454545454545455
# Experiment #8: Train AUC: 0.6359985396129976 Valid AUC: 0.6866310160427807
# Experiment #9: Train AUC: 0.6529950972722056 Valid AUC: 0.5326203208556151
#
# *********************************************************************************
# ldh
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6094825062216367 Valid AUC: 0.5444444444444445
# Experiment #1: Train AUC: 0.5574325557624211 Valid AUC: 0.5823863636363636
# Experiment #2: Train AUC: 0.5688040740335123 Valid AUC: 0.5539772727272727
# Experiment #3: Train AUC: 0.5688223268718287 Valid AUC: 0.5646306818181819
# Experiment #4: Train AUC: 0.5528333001105412 Valid AUC: 0.6439393939393939
# Experiment #5: Train AUC: 0.5801696174546509 Valid AUC: 0.5356060606060606
# Experiment #6: Train AUC: 0.5987804215066234 Valid AUC: 0.5212121212121212
# Experiment #7: Train AUC: 0.5802421035463821 Valid AUC: 0.4522727272727272
# Experiment #8: Train AUC: 0.573428410923654 Valid AUC: 0.5189393939393939
# Experiment #9: Train AUC: 0.5670768171357121 Valid AUC: 0.5848484848484848
#
# *********************************************************************************
# age
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6090990386765035 Valid AUC: 0.4975198412698413
# Experiment #1: Train AUC: 0.6177846298570644 Valid AUC: 0.4222689075630252
# Experiment #2: Train AUC: 0.6034910763280985 Valid AUC: 0.6349789915966386
# Experiment #3: Train AUC: 0.5910134042664164 Valid AUC: 0.7235294117647058
# Experiment #4: Train AUC: 0.6056498722161372 Valid AUC: 0.5524064171122995
# Experiment #5: Train AUC: 0.5983935742971889 Valid AUC: 0.6310160427807487
# Experiment #6: Train AUC: 0.6208796223856464 Valid AUC: 0.4502673796791444
# Experiment #7: Train AUC: 0.6014642987534554 Valid AUC: 0.5919786096256684
# Experiment #8: Train AUC: 0.6123976425181246 Valid AUC: 0.5352941176470588
# Experiment #9: Train AUC: 0.5992476399102905 Valid AUC: 0.5807486631016042
#
# *********************************************************************************
# gender
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5895503741402665 Valid AUC: 0.4955357142857143
# Experiment #1: Train AUC: 0.606535315790849 Valid AUC: 0.4459033613445378
# Experiment #2: Train AUC: 0.5920261830724607 Valid AUC: 0.5010504201680672
# Experiment #3: Train AUC: 0.5834572054451572 Valid AUC: 0.6197860962566845
# Experiment #4: Train AUC: 0.5940124132895217 Valid AUC: 0.49625668449197863
# Experiment #5: Train AUC: 0.5932561414489126 Valid AUC: 0.5620320855614973
# Experiment #6: Train AUC: 0.5966332863923225 Valid AUC: 0.4304812834224599
# Experiment #7: Train AUC: 0.587329838835863 Valid AUC: 0.5887700534759358
# Experiment #8: Train AUC: 0.595890053721379 Valid AUC: 0.48556149732620324
# Experiment #9: Train AUC: 0.5554947060971158 Valid AUC: 0.6064171122994652
#
# *********************************************************************************
# lga
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6289260385005067 Valid AUC: 0.6689189189189189
# Experiment #1: Train AUC: 0.6204034805411526 Valid AUC: 0.7387387387387389
# Experiment #2: Train AUC: 0.6294773228440312 Valid AUC: 0.6722972972972973
# Experiment #3: Train AUC: 0.626706001549556 Valid AUC: 0.5686936936936937
# Experiment #4: Train AUC: 0.6296219789299732 Valid AUC: 0.538083538083538
# Experiment #5: Train AUC: 0.6388733142503025 Valid AUC: 0.5589680589680589
# Experiment #6: Train AUC: 0.6392909679317446 Valid AUC: 0.5959595959595959
# Experiment #7: Train AUC: 0.6239923506913798 Valid AUC: 0.6022727272727273
# Experiment #8: Train AUC: 0.6345984112974405 Valid AUC: 0.494949494949495
# Experiment #9: Train AUC: 0.6226537216828479 Valid AUC: 0.648989898989899
#
# *********************************************************************************
# lgg
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5976030452625944 Valid AUC: 0.6954545454545454
# Experiment #1: Train AUC: 0.6180138384979876 Valid AUC: 0.5121212121212122
# Experiment #2: Train AUC: 0.6058803703483415 Valid AUC: 0.6204545454545455
# Experiment #3: Train AUC: 0.6206308610400681 Valid AUC: 0.6037878787878788
# Experiment #4: Train AUC: 0.6101809954751132 Valid AUC: 0.5795454545454546
# Experiment #5: Train AUC: 0.604366169544741 Valid AUC: 0.5946843853820598
# Experiment #6: Train AUC: 0.6008732339089482 Valid AUC: 0.7890365448504983
# Experiment #7: Train AUC: 0.6186028257456829 Valid AUC: 0.5406976744186046
# Experiment #8: Train AUC: 0.6108712715855573 Valid AUC: 0.5789036544850499
# Experiment #9: Train AUC: 0.5990875196232339 Valid AUC: 0.47093023255813954
#
# *********************************************************************************
# lgl_kappa
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5711443577908643 Valid AUC: 0.5
# Experiment #1: Train AUC: 0.5801687092153429 Valid AUC: 0.5281862745098038
# Experiment #2: Train AUC: 0.573436256565335 Valid AUC: 0.6433823529411765
# Experiment #3: Train AUC: 0.5748527773356678 Valid AUC: 0.4987745098039215
# Experiment #4: Train AUC: 0.5898933630431323 Valid AUC: 0.5073529411764706
# Experiment #5: Train AUC: 0.5788934426229508 Valid AUC: 0.5935828877005348
# Experiment #6: Train AUC: 0.5650693568726356 Valid AUC: 0.5441176470588236
# Experiment #7: Train AUC: 0.5972887767969735 Valid AUC: 0.45454545454545453
# Experiment #8: Train AUC: 0.592717528373266 Valid AUC: 0.7045454545454545
# Experiment #9: Train AUC: 0.5673391151332328 Valid AUC: 0.6694214876033058
#
# *********************************************************************************
# lgl_lambda
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.600912543108459 Valid AUC: 0.4712121212121212
# Experiment #1: Train AUC: 0.5735071879722556 Valid AUC: 0.7204545454545455
# Experiment #2: Train AUC: 0.5921842910838145 Valid AUC: 0.5553030303030303
# Experiment #3: Train AUC: 0.5727515790289457 Valid AUC: 0.703030303030303
# Experiment #4: Train AUC: 0.58299104894021 Valid AUC: 0.49015151515151517
# Experiment #5: Train AUC: 0.5972701205099392 Valid AUC: 0.4787878787878788
# Experiment #6: Train AUC: 0.5829295493001077 Valid AUC: 0.6201298701298701
# Experiment #7: Train AUC: 0.5798050299953853 Valid AUC: 0.648538961038961
# Experiment #8: Train AUC: 0.5871308016877638 Valid AUC: 0.574750830564784
# Experiment #9: Train AUC: 0.5934407364787111 Valid AUC: 0.5382059800664452
#
# *********************************************************************************
# lgm
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6009074447089463 Valid AUC: 0.6545454545454547
# Experiment #1: Train AUC: 0.6149748356197744 Valid AUC: 0.5705426356589147
# Experiment #2: Train AUC: 0.6117207635309277 Valid AUC: 0.5938538205980066
# Experiment #3: Train AUC: 0.6227851159793814 Valid AUC: 0.4642857142857143
# Experiment #4: Train AUC: 0.6224025451030928 Valid AUC: 0.5705980066445183
# Experiment #5: Train AUC: 0.6158182989690721 Valid AUC: 0.558139534883721
# Experiment #6: Train AUC: 0.6314432989690721 Valid AUC: 0.6686046511627907
# Experiment #7: Train AUC: 0.6129490173969072 Valid AUC: 0.5872093023255814
# Experiment #8: Train AUC: 0.6323795908505154 Valid AUC: 0.6503322259136213
# Experiment #9: Train AUC: 0.6061130798969072 Valid AUC: 0.6411960132890365
#
# *********************************************************************************
# m_protein
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6026944538066884 Valid AUC: 0.5478260869565217
# Experiment #1: Train AUC: 0.6037243006403776 Valid AUC: 0.5347826086956522
# Experiment #2: Train AUC: 0.6012994794592368 Valid AUC: 0.5565217391304348
# Experiment #3: Train AUC: 0.6057746320638131 Valid AUC: 0.5260869565217391
# Experiment #4: Train AUC: 0.602712746191007 Valid AUC: 0.5690993788819876
# Experiment #5: Train AUC: 0.609150873281308 Valid AUC: 0.5256211180124224
# Experiment #6: Train AUC: 0.6274247491638796 Valid AUC: 0.4906832298136646
# Experiment #7: Train AUC: 0.5895113340765515 Valid AUC: 0.6824534161490683
# Experiment #8: Train AUC: 0.5980769230769232 Valid AUC: 0.6133540372670807
# Experiment #9: Train AUC: 0.6342159048680789 Valid AUC: 0.5714285714285715
#
# *********************************************************************************
# first_line_transplant
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6497021343748768 Valid AUC: 0.5649801587301587
# Experiment #1: Train AUC: 0.6493375839452298 Valid AUC: 0.553046218487395
# Experiment #2: Train AUC: 0.6384018396090831 Valid AUC: 0.6586134453781513
# Experiment #3: Train AUC: 0.6303590987325927 Valid AUC: 0.7342245989304814
# Experiment #4: Train AUC: 0.6455171334689408 Valid AUC: 0.6085561497326203
# Experiment #5: Train AUC: 0.6362593230063109 Valid AUC: 0.6786096256684492
# Experiment #6: Train AUC: 0.6396755854587179 Valid AUC: 0.6064171122994653
# Experiment #7: Train AUC: 0.6284553799614041 Valid AUC: 0.6647058823529411
# Experiment #8: Train AUC: 0.6499765294946017 Valid AUC: 0.5727272727272726
# Experiment #9: Train AUC: 0.6390692640692641 Valid AUC: 0.6064171122994653
#
# *********************************************************************************
# cell_markers_cd117
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5919766967819992 Valid AUC: 0.4990079365079365
# Experiment #1: Train AUC: 0.6096579476861167 Valid AUC: 0.4227941176470588
# Experiment #2: Train AUC: 0.599473464161593 Valid AUC: 0.5625
# Experiment #3: Train AUC: 0.5588392531163615 Valid AUC: 0.5786096256684492
# Experiment #4: Train AUC: 0.5874341521931884 Valid AUC: 0.5839572192513369
# Experiment #5: Train AUC: 0.5945209409064831 Valid AUC: 0.6058823529411764
# Experiment #6: Train AUC: 0.5964702967715017 Valid AUC: 0.4368983957219251
# Experiment #7: Train AUC: 0.5728498409221301 Valid AUC: 0.5577540106951872
# Experiment #8: Train AUC: 0.5806342252125384 Valid AUC: 0.5171122994652406
# Experiment #9: Train AUC: 0.559465133260314 Valid AUC: 0.6668449197860963
#
# *********************************************************************************
# cell_markers_cd13
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5865322654883549 Valid AUC: 0.4930555555555556
# Experiment #1: Train AUC: 0.5943975541561055 Valid AUC: 0.4175420168067227
# Experiment #2: Train AUC: 0.5780919281925319 Valid AUC: 0.5414915966386554
# Experiment #3: Train AUC: 0.5714872476920669 Valid AUC: 0.625668449197861
# Experiment #4: Train AUC: 0.5770419339696448 Valid AUC: 0.5754010695187166
# Experiment #5: Train AUC: 0.5717741094247119 Valid AUC: 0.6235294117647059
# Experiment #6: Train AUC: 0.5922521253846555 Valid AUC: 0.41550802139037435
# Experiment #7: Train AUC: 0.5773353152871225 Valid AUC: 0.6074866310160427
# Experiment #8: Train AUC: 0.5840504876649455 Valid AUC: 0.5128342245989305
# Experiment #9: Train AUC: 0.5578287174672717 Valid AUC: 0.6352941176470588
#
# *********************************************************************************
# cell_markers_cd138
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5932588998040531 Valid AUC: 0.46726190476190477
# Experiment #1: Train AUC: 0.6050197287621835 Valid AUC: 0.421218487394958
# Experiment #2: Train AUC: 0.5932935273981552 Valid AUC: 0.5010504201680672
# Experiment #3: Train AUC: 0.5588392531163615 Valid AUC: 0.5786096256684492
# Experiment #4: Train AUC: 0.5972656861211078 Valid AUC: 0.5042780748663102
# Experiment #5: Train AUC: 0.5809667240390132 Valid AUC: 0.6513368983957218
# Experiment #6: Train AUC: 0.5974351953267616 Valid AUC: 0.4310160427807487
# Experiment #7: Train AUC: 0.5732540551817661 Valid AUC: 0.616577540106952
# Experiment #8: Train AUC: 0.5806342252125384 Valid AUC: 0.5171122994652406
# Experiment #9: Train AUC: 0.5742515516611902 Valid AUC: 0.6770053475935829
#
# *********************************************************************************
# cell_markers_cd38
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5865322654883549 Valid AUC: 0.4930555555555556
# Experiment #1: Train AUC: 0.5943975541561055 Valid AUC: 0.4175420168067227
# Experiment #2: Train AUC: 0.5780919281925319 Valid AUC: 0.5414915966386554
# Experiment #3: Train AUC: 0.5714872476920669 Valid AUC: 0.625668449197861
# Experiment #4: Train AUC: 0.5770419339696448 Valid AUC: 0.5754010695187166
# Experiment #5: Train AUC: 0.5717741094247119 Valid AUC: 0.6235294117647059
# Experiment #6: Train AUC: 0.5922521253846555 Valid AUC: 0.41550802139037435
# Experiment #7: Train AUC: 0.5733909664632557 Valid AUC: 0.6171122994652407
# Experiment #8: Train AUC: 0.584272153549262 Valid AUC: 0.5171122994652406
# Experiment #9: Train AUC: 0.5685208365931258 Valid AUC: 0.6304812834224599
#
# *********************************************************************************
# race_asian
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.5865322654883549 Valid AUC: 0.4930555555555556
# Experiment #1: Train AUC: 0.5943975541561055 Valid AUC: 0.4175420168067227
# Experiment #2: Train AUC: 0.5780919281925319 Valid AUC: 0.5414915966386554
# Experiment #3: Train AUC: 0.5686707870442811 Valid AUC: 0.6235294117647059
# Experiment #4: Train AUC: 0.5770419339696448 Valid AUC: 0.5754010695187166
# Experiment #5: Train AUC: 0.5723869503989987 Valid AUC: 0.6181818181818183
# Experiment #6: Train AUC: 0.5922521253846555 Valid AUC: 0.41550802139037435
# Experiment #7: Train AUC: 0.5733909664632557 Valid AUC: 0.6171122994652407
# Experiment #8: Train AUC: 0.5840504876649455 Valid AUC: 0.5128342245989305
# Experiment #9: Train AUC: 0.5685208365931258 Valid AUC: 0.6304812834224599
#
# *********************************************************************************
# race_black_african_american
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.582863192225247 Valid AUC: 0.4871031746031746
# Experiment #1: Train AUC: 0.5951814784812772 Valid AUC: 0.42384453781512604
# Experiment #2: Train AUC: 0.5711999268337297 Valid AUC: 0.520483193277311
# Experiment #3: Train AUC: 0.5714872476920669 Valid AUC: 0.625668449197861
# Experiment #4: Train AUC: 0.5800279038230846 Valid AUC: 0.5764705882352941
# Experiment #5: Train AUC: 0.5716632764825536 Valid AUC: 0.5919786096256684
# Experiment #6: Train AUC: 0.5922521253846555 Valid AUC: 0.41550802139037435
# Experiment #7: Train AUC: 0.57482527512648 Valid AUC: 0.6106951871657754
# Experiment #8: Train AUC: 0.5806342252125384 Valid AUC: 0.5171122994652406
# Experiment #9: Train AUC: 0.5673473113232149 Valid AUC: 0.6679144385026738
#
# *********************************************************************************
# race_other
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.582863192225247 Valid AUC: 0.4871031746031746
# Experiment #1: Train AUC: 0.589876923880948 Valid AUC: 0.351890756302521
# Experiment #2: Train AUC: 0.5780919281925319 Valid AUC: 0.5414915966386554
# Experiment #3: Train AUC: 0.5686707870442811 Valid AUC: 0.6235294117647059
# Experiment #4: Train AUC: 0.5770419339696448 Valid AUC: 0.5754010695187166
# Experiment #5: Train AUC: 0.5596802795597977 Valid AUC: 0.5080213903743316
# Experiment #6: Train AUC: 0.5922521253846555 Valid AUC: 0.41550802139037435
# Experiment #7: Train AUC: 0.5936473165388828 Valid AUC: 0.6272727272727273
# Experiment #8: Train AUC: 0.5972330881969435 Valid AUC: 0.5636363636363636
# Experiment #9: Train AUC: 0.5816512804464612 Valid AUC: 0.6422459893048128
#
# *********************************************************************************
# race_white
# *********************************************************************************
#
# Experiment #0: Train AUC: 0.6025170631632935 Valid AUC: 0.5168650793650793
# Experiment #1: Train AUC: 0.6160273328281376 Valid AUC: 0.40283613445378147
# Experiment #2: Train AUC: 0.5901839609083069 Valid AUC: 0.5241596638655461
# Experiment #3: Train AUC: 0.5588392531163615 Valid AUC: 0.5786096256684492
# Experiment #4: Train AUC: 0.5934973660877274 Valid AUC: 0.5860962566844921
# Experiment #5: Train AUC: 0.5813709382986492 Valid AUC: 0.6887700534759358
# Experiment #6: Train AUC: 0.5943709904553278 Valid AUC: 0.4294117647058824
# Experiment #7: Train AUC: 0.5835615188024826 Valid AUC: 0.6106951871657754
# Experiment #8: Train AUC: 0.5806342252125384 Valid AUC: 0.5171122994652406
# Experiment #9: Train AUC: 0.5586762634955406 Valid AUC: 0.660427807486631
#    experiment marker  train_auc  valid_auc  train_loss  valid_loss  \
# 0           0   cmmc   0.625117   0.512069    0.545428    0.573595
# 1           1   cmmc   0.642199   0.542857    0.536624    0.566508
# 2           2   cmmc   0.623808   0.450000    0.543624    0.565358
# 3           3   cmmc   0.648872   0.469643    0.532694    0.589842
# 4           4   cmmc   0.612578   0.842857    0.548261    0.521423
#
#    execution_time  threshold  accuracy  precision  sensitivity  specificity
# 0       21.451243   0.251666  0.743590       0.50          0.3     0.896552
# 1       22.181003   0.256543  0.421053       0.25          0.6     0.357143
# 2       22.201291   0.234144  0.736842       0.50          0.2     0.928571
# 3       23.670052   0.248062  0.526316       0.30          0.6     0.500000
# 4       21.362892   0.264713  0.842105       0.75          0.6     0.928571

# %%
result.groupby('marker').mean()
# Out:
#                                         experiment  train_auc  valid_auc  \
# marker
# absolute_neutrophil                            4.5   0.585290   0.541534
# age                                            4.5   0.605942   0.562001
# albumin                                        4.5   0.609315   0.579936
# beta_2_microglobulin                           4.5   0.628372   0.577573
# bun                                            4.5   0.641997   0.609779
# calcium                                        4.5   0.578878   0.557695
# cell_markers_cd117                             4.5   0.585132   0.543136
# cell_markers_cd13                              4.5   0.579079   0.544781
# cell_markers_cd138                             4.5   0.585422   0.536547
# cell_markers_cd38                              4.5   0.579776   0.545690
# cmmc                                           4.5   0.633308   0.579957
# creatinine                                     4.5   0.594262   0.564344
# ecog_ps                                        4.5   0.598866   0.531672
# first_line_transplant                          4.5   0.640675   0.624830
# gender                                         4.5   0.589419   0.523179
# glucose                                        4.5   0.612424   0.602999
# hemoglobin                                     4.5   0.634246   0.577364
# iss                                            4.5   0.578609   0.538041
# ldh                                            4.5   0.575707   0.550226
# lga                                            4.5   0.629454   0.608787
# lgg                                            4.5   0.608611   0.598562
# lgl_kappa                                      4.5   0.579080   0.564391
# lgl_lambda                                     4.5   0.586292   0.580057
# lgm                                            4.5   0.617149   0.595931
# m_protein                                      4.5   0.607459   0.561786
# percent_aneuploid                              4.5   0.660948   0.644934
# percent_plama_cells_bone_marrow                4.5   0.605053   0.597155
# percent_plama_cells_peripherical_blood         4.5   0.642756   0.625003
# platelet                                       4.5   0.579572   0.544863
# race_asian                                     4.5   0.579534   0.544514
# race_black_african_american                    4.5   0.578748   0.543678
# race_other                                     4.5   0.582101   0.533610
# race_white                                     4.5   0.585968   0.551498
# total_protein                                  4.5   0.609435   0.594449
# wbc_x10_10_9_l                                 4.5   0.607940   0.603455
#
#                                         train_loss  valid_loss  \
# marker
# absolute_neutrophil                       0.539001    0.544222
# age                                       0.536214    0.543213
# albumin                                   0.533329    0.538743
# beta_2_microglobulin                      0.546628    0.551963
# bun                                       0.542008    0.549879
# calcium                                   0.539838    0.541441
# cell_markers_cd117                        0.540114    0.547788
# cell_markers_cd13                         0.537039    0.546268
# cell_markers_cd138                        0.539267    0.545970
# cell_markers_cd38                         0.536527    0.544487
# cmmc                                      0.542111    0.552803
# creatinine                                0.539694    0.545167
# ecog_ps                                   0.519991    0.528745
# first_line_transplant                     0.525274    0.532428
# gender                                    0.539067    0.547861
# glucose                                   0.541673    0.546098
# hemoglobin                                0.532381    0.544269
# iss                                       0.540066    0.545481
# ldh                                       0.565030    0.569138
# lga                                       0.530516    0.540575
# lgg                                       0.551868    0.558964
# lgl_kappa                                 0.561060    0.563753
# lgl_lambda                                0.551207    0.554289
# lgm                                       0.547285    0.552079
# m_protein                                 0.540807    0.545451
# percent_aneuploid                         0.538927    0.548791
# percent_plama_cells_bone_marrow           0.542458    0.549414
# percent_plama_cells_peripherical_blood    0.531506    0.540759
# platelet                                  0.538500    0.544943
# race_asian                                0.537037    0.545564
# race_black_african_american               0.539431    0.544868
# race_other                                0.537801    0.547869
# race_white                                0.539690    0.545125
# total_protein                             0.546195    0.549462
# wbc_x10_10_9_l                            0.541597    0.548661
#
#                                         execution_time  threshold  accuracy  \
# marker
# absolute_neutrophil                          20.126997   0.234407  0.424406
# age                                          20.393987   0.232819  0.462878
# albumin                                      20.168885   0.236793  0.513149
# beta_2_microglobulin                         20.573004   0.243988  0.485031
# bun                                          21.736295   0.237918  0.492857
# calcium                                      19.987270   0.228363  0.372902
# cell_markers_cd117                           20.068154   0.223151  0.348206
# cell_markers_cd13                            20.220546   0.217740  0.361905
# cell_markers_cd138                           20.183146   0.225180  0.385459
# cell_markers_cd38                            20.536801   0.216621  0.367384
# cmmc                                         21.881491   0.246930  0.567531
# creatinine                                   19.906685   0.227446  0.416578
# ecog_ps                                      20.602595   0.227817  0.483571
# first_line_transplant                        21.572133   0.237020  0.533526
# gender                                       20.348305   0.221650  0.371402
# glucose                                      20.253858   0.239012  0.472564
# hemoglobin                                   20.636235   0.242776  0.477778
# iss                                          19.764765   0.234421  0.429190
# ldh                                          19.692857   0.256942  0.465309
# lga                                          21.442913   0.221700  0.517979
# lgg                                          20.388298   0.237262  0.468707
# lgl_kappa                                    20.044517   0.248683  0.465220
# lgl_lambda                                   20.234708   0.240574  0.441931
# lgm                                          20.726793   0.226664  0.472062
# m_protein                                    19.733648   0.232705  0.453470
# percent_aneuploid                            22.166644   0.251525  0.569276
# percent_plama_cells_bone_marrow              20.315692   0.232218  0.439898
# percent_plama_cells_peripherical_blood       21.704779   0.233029  0.470271
# platelet                                     19.999138   0.225511  0.350032
# race_asian                                   20.311603   0.218861  0.372940
# race_black_african_american                  19.976200   0.229356  0.364568
# race_other                                   20.663263   0.222354  0.420238
# race_white                                   20.011106   0.225650  0.374633
# total_protein                                20.443650   0.239932  0.421570
# wbc_x10_10_9_l                               20.432480   0.239671  0.447857
#
#                                         precision  sensitivity  specificity
# marker
# absolute_neutrophil                      0.244360     0.733824     0.329630
# age                                      0.335695     0.703268     0.389026
# albumin                                  0.313623     0.598529     0.487542
# beta_2_microglobulin                     0.270905     0.649583     0.431353
# bun                                      0.280284     0.650000     0.440476
# calcium                                  0.244421     0.841176     0.228249
# cell_markers_cd117                       0.244954     0.859477     0.189935
# cell_markers_cd13                        0.245229     0.835948     0.215065
# cell_markers_cd138                       0.257296     0.853595     0.240714
# cell_markers_cd38                        0.261343     0.918301     0.197045
# cmmc                                     0.346581     0.574444     0.568227
# creatinine                               0.253422     0.764706     0.308552
# ecog_ps                                  0.308594     0.587500     0.452646
# first_line_transplant                    0.287591     0.661765     0.494481
# gender                                   0.241095     0.795752     0.240227
# glucose                                  0.281690     0.726190     0.391884
# hemoglobin                               0.240770     0.592484     0.442565
# iss                                      0.244766     0.696324     0.346401
# ldh                                      0.276218     0.675417     0.392273
# lga                                      0.302672     0.711364     0.458483
# lgg                                      0.276638     0.747143     0.375846
# lgl_kappa                                0.276972     0.680303     0.392513
# lgl_lambda                               0.285037     0.748095     0.340433
# lgm                                      0.295050     0.741905     0.384302
# m_protein                                0.269061     0.694286     0.378261
# percent_aneuploid                        0.327536     0.587912     0.562622
# percent_plama_cells_bone_marrow          0.276760     0.793333     0.327428
# percent_plama_cells_peripherical_blood   0.278981     0.740000     0.385014
# platelet                                 0.246572     0.865359     0.190130
# race_asian                               0.261776     0.906536     0.207955
# race_black_african_american              0.248292     0.847712     0.214740
# race_other                               0.215892     0.688889     0.336883
# race_white                               0.244859     0.806536     0.240942
# total_protein                            0.276129     0.823810     0.291208
# wbc_x10_10_9_l                           0.268797     0.746667     0.352775

# %%
result.groupby('marker').std()
# Out:
#                                         experiment  train_auc  valid_auc  \
# marker
# absolute_neutrophil                        3.02765   0.023021   0.085133
# age                                        3.02765   0.009224   0.090923
# albumin                                    3.02765   0.034952   0.047948
# beta_2_microglobulin                       3.02765   0.026504   0.050716
# bun                                        3.02765   0.016713   0.084248
# calcium                                    3.02765   0.015370   0.083027
# cell_markers_cd117                         3.02765   0.016988   0.075386
# cell_markers_cd13                          3.02765   0.010848   0.083276
# cell_markers_cd138                         3.02765   0.014198   0.090059
# cell_markers_cd38                          3.02765   0.009103   0.083402
# cmmc                                       3.02765   0.016751   0.146485
# creatinine                                 3.02765   0.020212   0.071640
# ecog_ps                                    3.02765   0.011674   0.073899
# first_line_transplant                      3.02765   0.007821   0.057719
# gender                                     3.02765   0.013418   0.066693
# glucose                                    3.02765   0.021412   0.045003
# hemoglobin                                 3.02765   0.015800   0.092613
# iss                                        3.02765   0.010756   0.056827
# ldh                                        3.02765   0.017466   0.050442
# lga                                        3.02765   0.006479   0.073339
# lgg                                        3.02765   0.008416   0.090706
# lgl_kappa                                  3.02765   0.010967   0.083838
# lgl_lambda                                 3.02765   0.009614   0.090497
# lgm                                        3.02765   0.010192   0.061329
# m_protein                                  3.02765   0.013448   0.053703
# percent_aneuploid                          3.02765   0.010496   0.062997
# percent_plama_cells_bone_marrow            3.02765   0.015479   0.079296
# percent_plama_cells_peripherical_blood     3.02765   0.021499   0.074089
# platelet                                   3.02765   0.013607   0.096028
# race_asian                                 3.02765   0.009360   0.082805
# race_black_african_american                3.02765   0.009308   0.085172
# race_other                                 3.02765   0.011791   0.094961
# race_white                                 3.02765   0.017822   0.092063
# total_protein                              3.02765   0.011480   0.075501
# wbc_x10_10_9_l                             3.02765   0.020804   0.080209
#
#                                         train_loss  valid_loss  \
# marker
# absolute_neutrophil                       0.003903    0.017299
# age                                       0.002403    0.009998
# albumin                                   0.004691    0.005842
# beta_2_microglobulin                      0.004443    0.009605
# bun                                       0.003069    0.015963
# calcium                                   0.003081    0.007935
# cell_markers_cd117                        0.003134    0.012339
# cell_markers_cd13                         0.003548    0.015057
# cell_markers_cd138                        0.003493    0.010276
# cell_markers_cd38                         0.002704    0.016330
# cmmc                                      0.006827    0.027419
# creatinine                                0.002642    0.008294
# ecog_ps                                   0.003865    0.012517
# first_line_transplant                     0.003066    0.015013
# gender                                    0.003570    0.010946
# glucose                                   0.004623    0.010355
# hemoglobin                                0.004401    0.015002
# iss                                       0.003301    0.014010
# ldh                                       0.002583    0.007354
# lga                                       0.006096    0.016268
# lgg                                       0.004856    0.010273
# lgl_kappa                                 0.003135    0.009917
# lgl_lambda                                0.002581    0.014971
# lgm                                       0.003802    0.011016
# m_protein                                 0.003105    0.012297
# percent_aneuploid                         0.004800    0.012394
# percent_plama_cells_bone_marrow           0.005427    0.014541
# percent_plama_cells_peripherical_blood    0.008563    0.019285
# platelet                                  0.002688    0.014579
# race_asian                                0.003303    0.015593
# race_black_african_american               0.003299    0.012897
# race_other                                0.003529    0.015785
# race_white                                0.003713    0.010797
# total_protein                             0.003746    0.011517
# wbc_x10_10_9_l                            0.005206    0.017301
#
#                                         execution_time  threshold  accuracy  \
# marker
# absolute_neutrophil                           0.786957   0.006923  0.101815
# age                                           0.391031   0.012983  0.121719
# albumin                                       0.666975   0.012753  0.156860
# beta_2_microglobulin                          0.678987   0.015461  0.068511
# bun                                           0.515540   0.015043  0.093055
# calcium                                       0.378779   0.021263  0.071345
# cell_markers_cd117                            0.655031   0.017736  0.073527
# cell_markers_cd13                             0.545243   0.025736  0.052783
# cell_markers_cd138                            1.119183   0.014627  0.077437
# cell_markers_cd38                             0.534778   0.024334  0.036668
# cmmc                                          1.060861   0.010421  0.191225
# creatinine                                    0.548324   0.014329  0.088994
# ecog_ps                                       0.809556   0.006521  0.136967
# first_line_transplant                         0.402603   0.031282  0.115738
# gender                                        0.750249   0.015579  0.080375
# glucose                                       0.668216   0.009645  0.110097
# hemoglobin                                    0.411648   0.019275  0.085423
# iss                                           0.728425   0.009521  0.092592
# ldh                                           0.312118   0.014020  0.060222
# lga                                           1.061511   0.020619  0.102947
# lgg                                           0.818545   0.013764  0.089245
# lgl_kappa                                     1.181883   0.010908  0.141860
# lgl_lambda                                    0.789364   0.022390  0.120683
# lgm                                           1.319831   0.017569  0.131676
# m_protein                                     0.628373   0.009813  0.139904
# percent_aneuploid                             0.693336   0.014578  0.110989
# percent_plama_cells_bone_marrow               0.970825   0.012278  0.095162
# percent_plama_cells_peripherical_blood        1.396872   0.008987  0.080806
# platelet                                      0.426615   0.008936  0.053690
# race_asian                                    0.349315   0.027066  0.043803
# race_black_african_american                   0.593268   0.014799  0.066428
# race_other                                    0.644152   0.031201  0.140025
# race_white                                    0.398250   0.016223  0.097737
# total_protein                                 0.465612   0.008415  0.083219
# wbc_x10_10_9_l                                0.904184   0.012791  0.106512
#
#                                         precision  sensitivity  specificity
# marker
# absolute_neutrophil                      0.064110     0.302198     0.195358
# age                                      0.234899     0.285315     0.240093
# albumin                                  0.257025     0.354693     0.302427
# beta_2_microglobulin                     0.039730     0.216350     0.137033
# bun                                      0.064431     0.263953     0.190889
# calcium                                  0.044365     0.251179     0.160534
# cell_markers_cd117                       0.039695     0.198514     0.129138
# cell_markers_cd13                        0.039133     0.187856     0.096706
# cell_markers_cd138                       0.018138     0.167095     0.144929
# cell_markers_cd38                        0.016722     0.068705     0.045127
# cmmc                                     0.201134     0.322288     0.340233
# creatinine                               0.028859     0.211183     0.174261
# ecog_ps                                  0.251690     0.300751     0.240758
# first_line_transplant                    0.047403     0.220643     0.198652
# gender                                   0.040907     0.236708     0.153182
# glucose                                  0.037325     0.206572     0.202751
# hemoglobin                               0.057066     0.259982     0.168394
# iss                                      0.034923     0.263838     0.192156
# ldh                                      0.028111     0.208032     0.147228
# lga                                      0.071678     0.140756     0.155380
# lgg                                      0.059761     0.246747     0.170730
# lgl_kappa                                0.041173     0.279991     0.271664
# lgl_lambda                               0.055697     0.193722     0.211385
# lgm                                      0.045018     0.173282     0.226843
# m_protein                                0.070835     0.204630     0.228278
# percent_aneuploid                        0.049988     0.214450     0.212555
# percent_plama_cells_bone_marrow          0.032867     0.110889     0.139897
# percent_plama_cells_peripherical_blood   0.034800     0.138600     0.124862
# platelet                                 0.048193     0.192295     0.054547
# race_asian                               0.017268     0.062997     0.057430
# race_black_african_american              0.040504     0.188627     0.113742
# race_other                               0.085142     0.354487     0.280998
# race_white                               0.038602     0.240466     0.179289
# total_protein                            0.020849     0.131679     0.145173
# wbc_x10_10_9_l                           0.043776     0.210350     0.182732

# %%
result.groupby('marker').mean().mean()
# Out:
# experiment         4.500000
# train_auc          0.602766
# valid_auc          0.570970
# train_loss         0.540318
# valid_loss         0.547044
# execution_time    20.492841
# threshold          0.233048
# accuracy           0.442351
# precision          0.272282
# sensitivity        0.738518
# specificity        0.349309
# dtype: float64
