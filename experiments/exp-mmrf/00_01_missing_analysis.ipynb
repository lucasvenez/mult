# %% [markdown]
# # Loading Required Libraries

# %%
import pandas as pd
import missingno as msno

# %matplotlib inline

# %% [markdown]
# # Loading Data Set

# %%
df = pd.read_csv('data/input.tsv', sep='\t', index_col='ID')

df.iloc[:10, :]
# Out:
#           cmmc                                            ecog_ps  \
# ID
# MMRF1007   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1011   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1013   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1014   NaN                                PS 0 (Fully Active)
# MMRF1015   NaN                                PS 0 (Fully Active)
# MMRF1016   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1017   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1018   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1020   NaN                                PS 0 (Fully Active)
# MMRF1021   NaN  PS 1 (Restricted in physically strenuous activ...
#
#          cell_markers  dna_index  lgh     lgl  percent_aneuploid  \
# ID
# MMRF1007        CD117        NaN  IgG   Kappa                0.0
# MMRF1011        CD138        NaN  NaN     NaN                0.0
# MMRF1013        CD117        NaN  NaN     NaN                0.0
# MMRF1014        CD117        NaN  IgA   Kappa                0.0
# MMRF1015          NaN        NaN  NaN     NaN                NaN
# MMRF1016        CD117        NaN  IgG  Lambda                0.0
# MMRF1017        CD138       1.25  IgG  Lambda                6.9
# MMRF1018        CD117        NaN  IgA   Kappa                0.0
# MMRF1020        CD138        NaN  NaN     NaN                0.0
# MMRF1021         CD13        NaN  IgG   Kappa                0.0
#
#           percent_plama_cells_bone_marrow  \
# ID
# MMRF1007                              0.6
# MMRF1011                              0.9
# MMRF1013                              1.3
# MMRF1014                              1.4
# MMRF1015                              NaN
# MMRF1016                              2.0
# MMRF1017                              2.1
# MMRF1018                              2.1
# MMRF1020                              4.0
# MMRF1021                              4.9
#
#           percent_plama_cells_peripherical_blood  creatinine  ...  lgl_lambda  \
# ID                                                            ...
# MMRF1007                                     0.0     176.800  ...       1.520
# MMRF1011                                     0.0     123.760  ...       5.110
# MMRF1013                                     0.2     186.524  ...       0.660
# MMRF1014                                     0.0      70.720  ...         NaN
# MMRF1015                                     NaN         NaN  ...         NaN
# MMRF1016                                     0.0      86.632  ...       6.350
# MMRF1017                                     0.0      79.560  ...         NaN
# MMRF1018                                     0.0     133.484  ...       2.254
# MMRF1020                                     0.0      88.400  ...       0.235
# MMRF1021                                     0.0      88.400  ...       3.280
#
#            lgm  m_protein  therapy_first_line  \
# ID
# MMRF1007  0.10       3.70                 NaN
# MMRF1011   NaN       3.50             Bor-Dex
# MMRF1013  0.21       0.10         Bor-Len-Dex
# MMRF1014   NaN       2.20             Bor-Dex
# MMRF1015   NaN        NaN                 NaN
# MMRF1016  1.26       2.69         Bor-Cyc-Dex
# MMRF1017   NaN       2.20             Len-Dex
# MMRF1018  0.28       2.16             Len-Dex
# MMRF1020  0.20       0.45         Bor-Len-Dex
# MMRF1021  0.40       3.05         Bor-Len-Dex
#
#                              therapy_first_line_class  first_line_transplant  \
# ID
# MMRF1007              Combined bortezomib/IMIDs-based                     No
# MMRF1011              Combined bortezomib/IMIDs-based                    Yes
# MMRF1013              Combined bortezomib/IMIDs-based                    Yes
# MMRF1014  Combined bortezomib/IMIDs/carfilzomib-based                    Yes
# MMRF1015                                          NaN                    NaN
# MMRF1016              Combined bortezomib/IMIDs-based                     No
# MMRF1017                                  IMIDs-based                     No
# MMRF1018              Combined bortezomib/IMIDs-based                     No
# MMRF1020                                          NaN                    Yes
# MMRF1021                                          NaN                    Yes
#
#           response_best_response_first_line  \
# ID
# MMRF1007                                0.0
# MMRF1011                                0.0
# MMRF1013                                1.0
# MMRF1014                                0.0
# MMRF1015                                NaN
# MMRF1016                                0.0
# MMRF1017                                0.0
# MMRF1018                                0.0
# MMRF1020                                1.0
# MMRF1021                                0.0
#
#           response_days_to_disease_progression  \
# ID
# MMRF1007                                   0.0
# MMRF1011                                   1.0
# MMRF1013                                   1.0
# MMRF1014                                   NaN
# MMRF1015                                   NaN
# MMRF1016                                   1.0
# MMRF1017                                   0.0
# MMRF1018                                   NaN
# MMRF1020                                   1.0
# MMRF1021                                   1.0
#
#           response_days_to_first_response  \
# ID
# MMRF1007                              NaN
# MMRF1011                              0.0
# MMRF1013                              1.0
# MMRF1014                              1.0
# MMRF1015                              NaN
# MMRF1016                              1.0
# MMRF1017                              0.0
# MMRF1018                              1.0
# MMRF1020                              1.0
# MMRF1021                              0.0
#
#           response_best_response_and_days_to_first_therapy
# ID
# MMRF1007                                               NaN
# MMRF1011                                               0.0
# MMRF1013                                               1.0
# MMRF1014                                               0.0
# MMRF1015                                               NaN
# MMRF1016                                               0.0
# MMRF1017                                               0.0
# MMRF1018                                               0.0
# MMRF1020                                               1.0
# MMRF1021                                               0.0
#
# [10 rows x 62 columns]

# %% [markdown]
# # Visualize Variables with or without Missing Values

# %%
msno.matrix(df);

# %% [markdown]
# # Visualizing Variables with Less than of 10% of Missing Values

# %%
selected_columns = []

for c in df:
    
    series = df[c]
    
    if series.isnull().sum() / len(series) <= .6 or c in ('response_days_to_disease_progression', 'therapy_first_line', 'response_best_response_and_days_to_first_therapy'):
        selected_columns.append(c)
        
selected_columns = selected_columns[-4:] + selected_columns[:-4]

msno.matrix(df[selected_columns]);

# %%
clinical_description = {'variable': [], 'type': [], 'number of values': [], 'sample':[], 'nas': [], 'count': []}

for c in selected_columns:
        
    clinical_description['variable'].append(c)
    
    clinical_description['type'].append(str(df[c].dtype))
    
    nvalues = len(df[c].unique())
    
    clinical_description['number of values'].append(nvalues)
    
    clinical_description['nas'].append(df[c].isnull().sum())
    
    clinical_description['count'].append((~df[c].isnull()).sum())
    
    try:
        clinical_description['sample'].append(', '.join([str(v) for v in df[c].unique()[:min(5, nvalues)]]))
        
    except:
        clinical_description['sample'].append(None)

clinical_description = pd.DataFrame(clinical_description)

clinical_description
# Out:
#                                             variable     type  \
# 0                  response_best_response_first_line  float64
# 1               response_days_to_disease_progression  float64
# 2                    response_days_to_first_response  float64
# 3   response_best_response_and_days_to_first_therapy  float64
# 4                                               cmmc  float64
# 5                                            ecog_ps   object
# 6                                       cell_markers   object
# 7                                  percent_aneuploid  float64
# 8                    percent_plama_cells_bone_marrow  float64
# 9             percent_plama_cells_peripherical_blood  float64
# 10                                        creatinine  float64
# 11                                               iss  float64
# 12                               absolute_neutrophil  float64
# 13                                          platelet  float64
# 14                                    wbc_x10_10_9_l  float64
# 15                                               bun  float64
# 16                                           glucose  float64
# 17                                     total_protein  float64
# 18                                           albumin  float64
# 19                              beta_2_microglobulin  float64
# 20                                           calcium  float64
# 21                                        hemoglobin  float64
# 22                                               ldh  float64
# 23                                               age  float64
# 24                                     family_cancer   object
# 25                                            gender   object
# 26                                              race   object
# 27                                 hyperdiploid_flag   object
# 28                                             13q14   object
# 29                                             13q34   object
# 30                                             17p13   object
# 31                                              1q21   object
# 32                                             11p15   object
# 33                                             15q15   object
# 34                                             19q13   object
# 35                                             20q13   object
# 36                                             21q22   object
# 37                                              3q21   object
# 38                                              5q31   object
# 39                                              7q22   object
# 40                                              9q33   object
# 41                                     t_11_14_ccnd1   object
# 42                                     t_12_14_ccnd2   object
# 43                                       t_14_16_maf   object
# 44                                      t_14_20_mafb   object
# 45                                      t_4_14_whsc1   object
# 46                                      t_6_14_ccnd3   object
# 47                                       t_8_14_mafa   object
# 48                                        t_8_14_myc   object
# 49                                               lga  float64
# 50                                               lgg  float64
# 51                                         lgl_kappa  float64
# 52                                        lgl_lambda  float64
# 53                                               lgm  float64
# 54                                         m_protein  float64
# 55                                therapy_first_line   object
# 56                          therapy_first_line_class   object
# 57                             first_line_transplant   object
#
#     number of values                                             sample  nas  \
# 0                  3                                      0.0, 1.0, nan  454
# 1                  3                                      0.0, 1.0, nan  965
# 2                  3                                      nan, 0.0, 1.0  506
# 3                  3                                      nan, 0.0, 1.0  511
# 4                660                nan, 800.0, 5913.0, 22169.0, 3864.0  610
# 5                  6  PS 1 (Restricted in physically strenuous activ...  672
# 6                  5                      CD117, CD138, nan, CD13, CD38  562
# 7                323                          0.0, nan, 6.9, 11.0, 15.4  671
# 8                406                            0.6, 0.9, 1.3, 1.4, nan  556
# 9                 94                           0.0, 0.2, nan, 34.0, 3.0  565
# 10               317                 176.8, 123.76, 186.524, 70.72, nan  401
# 11                 4                                 3.0, 1.0, nan, 2.0  411
# 12               431                          5.1, 8.28, 4.33, 1.3, nan  410
# 13               317                    200.0, 170.0, 245.0, 212.0, nan  383
# 14               218                            6.1, 8.9, 7.1, 2.8, nan  555
# 15               104      20.349, 7.854, 11.424000000000001, 3.927, nan  635
# 16               170                        9.79, 7.15, 5.39, 4.29, nan  571
# 17               121                           9.2, 10.8, 7.1, 8.7, nan  585
# 18               126                        33.0, 25.0, 40.0, 41.0, nan  400
# 19               416                        nan, 7.84, 2.92, 3.15, 6.72  572
# 20               182                          2.5, 1.975, 2.3, 2.2, nan  395
# 21               150  6.757999999999999, 6.013999999999999, 7.006, n...  384
# 22               309  nan, 2.15043, 1.8337, 3.8174300000000003, 2.93392  593
# 23                63                       78.0, 50.0, 66.0, 64.0, 56.0  371
# 24                 4                                  No, Yes, Unk, nan  543
# 25                 3                                  Male, Female, nan  371
# 26                 6   White, Asian, Black/African American, Other, nan  543
# 27                 3                        nan, Detected, Not Detected  807
# 28                 3                        nan, Detected, Not Detected  807
# 29                 3                        nan, Detected, Not Detected  807
# 30                 3                        nan, Not Detected, Detected  807
# 31                 3                        nan, Detected, Not Detected  807
# 32                 3                        nan, Not Detected, Detected  807
# 33                 3                        nan, Detected, Not Detected  807
# 34                 3                        nan, Detected, Not Detected  807
# 35                 3                        nan, Not Detected, Detected  807
# 36                 3                        nan, Not Detected, Detected  807
# 37                 3                        nan, Detected, Not Detected  807
# 38                 3                        nan, Detected, Not Detected  807
# 39                 3                        nan, Not Detected, Detected  807
# 40                 3                        nan, Detected, Not Detected  807
# 41                 3                        nan, Not Detected, Detected  814
# 42                 3                        nan, Not Detected, Detected  814
# 43                 3                        nan, Not Detected, Detected  814
# 44                 3                        nan, Not Detected, Detected  814
# 45                 3                        nan, Detected, Not Detected  814
# 46                 3                        nan, Not Detected, Detected  814
# 47                 3                        nan, Not Detected, Detected  814
# 48                 3                        nan, Not Detected, Detected  814
# 49               241                         0.12, nan, 0.2, 0.54, 1.64  774
# 50               790                     52.76, nan, 5.27, 29.53, 12.49  623
# 51               593                      nan, 0.85, 15.9, 0.598, 48.57  802
# 52               649                        1.52, 5.11, 0.66, nan, 6.35  601
# 53               165                         0.1, nan, 0.21, 1.26, 0.28  633
# 54               417                            3.7, 3.5, 0.1, 2.2, nan  571
# 55                 7    nan, Bor-Dex, Bor-Len-Dex, Bor-Cyc-Dex, Len-Dex  738
# 56                 8  Combined bortezomib/IMIDs-based, Combined bort...  443
# 57                 3                                       No, Yes, nan  382
#
#     count
# 0    1071
# 1     560
# 2    1019
# 3    1014
# 4     915
# 5     853
# 6     963
# 7     854
# 8     969
# 9     960
# 10   1124
# 11   1114
# 12   1115
# 13   1142
# 14    970
# 15    890
# 16    954
# 17    940
# 18   1125
# 19    953
# 20   1130
# 21   1141
# 22    932
# 23   1154
# 24    982
# 25   1154
# 26    982
# 27    718
# 28    718
# 29    718
# 30    718
# 31    718
# 32    718
# 33    718
# 34    718
# 35    718
# 36    718
# 37    718
# 38    718
# 39    718
# 40    718
# 41    711
# 42    711
# 43    711
# 44    711
# 45    711
# 46    711
# 47    711
# 48    711
# 49    751
# 50    902
# 51    723
# 52    924
# 53    892
# 54    954
# 55    787
# 56   1082
# 57   1143

# %% [markdown]
# # Exporting data set composed by variables with less than 10% of missing values

# %%
df[selected_columns].loc[~(df[selected_columns[0]].isnull() & df[selected_columns[1]].isnull())].to_csv('data/clinical.tsv', sep='\t', index=True)
