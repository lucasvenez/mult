# %% [markdown]
# # Loading Clinical Data

# %%
from optimization import lightgbm_optimizer

import pandas as pd
import numpy as np

dataset = pd.read_csv('data/input.tsv', sep='\t', index_col='ID')
dataset = dataset.loc[~dataset.index.duplicated(keep='first')]

dataset = dataset.loc[~dataset['therapy_first_line_class'].isnull()]

therapy_class = pd.get_dummies(dataset['therapy_first_line_class'])
therapy = pd.get_dummies(dataset['therapy_first_line'])

del dataset['therapy_first_line']
del dataset['therapy_first_line_class']

# removing unused outcome markers
# response_best_response_first_line ! Warning: we are using that outcome marker
del dataset['response_days_to_disease_progression']
del dataset['response_days_to_first_response']
del dataset['response_best_response_and_days_to_first_therapy']

dataset = dataset.loc[dataset['response_best_response_first_line'].notnull(),:]

display(dataset.iloc[:8, :8])
print(dataset.shape)
# Out:
#           cmmc                                            ecog_ps  \
# ID
# MMRF1007   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1011   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1013   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1014   NaN                                PS 0 (Fully Active)
# MMRF1016   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1017   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1018   NaN  PS 1 (Restricted in physically strenuous activ...
# MMRF1024   NaN  PS 1 (Restricted in physically strenuous activ...
#
#          cell_markers  dna_index  lgh     lgl  percent_aneuploid  \
# ID
# MMRF1007        CD117        NaN  IgG   Kappa                0.0
# MMRF1011        CD138        NaN  NaN     NaN                0.0
# MMRF1013        CD117        NaN  NaN     NaN                0.0
# MMRF1014        CD117        NaN  IgA   Kappa                0.0
# MMRF1016        CD117        NaN  IgG  Lambda                0.0
# MMRF1017        CD138       1.25  IgG  Lambda                6.9
# MMRF1018        CD117        NaN  IgA   Kappa                0.0
# MMRF1024        CD117       1.15  IgG   Kappa               11.0
#
#           percent_plama_cells_bone_marrow
# ID
# MMRF1007                              0.6
# MMRF1011                              0.9
# MMRF1013                              1.3
# MMRF1014                              1.4
# MMRF1016                              2.0
# MMRF1017                              2.1
# MMRF1018                              2.1
# MMRF1024                              6.0
# (1013, 57)

# %%
to_delete = []

for c in therapy.columns:
    if therapy[c].sum() < 10:
        to_delete.append(c)

for c in to_delete:
    del therapy[c]

display(therapy.head())

print('{} rows X {} columns'.format(*therapy.shape))
# Out:
#           Bor  Bor-Cyc-Dex  Bor-Dex  Bor-Len-Dex  Len-Dex
# ID
# MMRF1007    0            0        0            0        0
# MMRF1011    0            0        1            0        0
# MMRF1013    0            0        0            1        0
# MMRF1014    0            0        1            0        0
# MMRF1016    0            1        0            0        0
# 1082 rows X 5 columns

# %% [markdown]
# # Loading Gene Expressions (FPKM)

# %%
# loading gene fpkm
gene_fpkm = pd.read_csv('data/gene_fpkm.txt', sep='\t', index_col='GENE_ID')

# removing data not collected at the first trail
for col in gene_fpkm.columns:
    if '_1_' not in col:
        del gene_fpkm[col]

# transpose matrix, delete patients and gene with all nan, and replace remainder missing by zero
gene_fpkm = gene_fpkm.T.dropna(how='all', axis=0).dropna(how='all', axis=1).fillna(0)

# replace id column name
gene_fpkm.index.name = 'ID'

# normalize index value transforming mmrf ids to integers
gene_fpkm.index = [int(col.split('_')[1]) for col in gene_fpkm.index]

# removing genes with zero sum
gene_fpkm = gene_fpkm[list(gene_fpkm.sum(axis=0).index[(gene_fpkm.sum(axis=0) > 0).tolist()])]
gene_fpkm.index = ['MMRF' + str(m) for m in gene_fpkm.index]

gene_fpkm = gene_fpkm.loc[~gene_fpkm.index.duplicated(keep='first')]

gene_fpkm.shape
# Out:
# (769, 49872)

# %% [markdown]
# # Creating Models

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report
from datetime import datetime
from correlation import select_genes
from evaluation import optimize_threshold, classification_metrics

import lightgbm as lgb
import numpy as np
import pickle

import warnings
warnings.filterwarnings('ignore')

result = None

N_FOLDS, RANDOM_STATE = 10, 13

kfold = StratifiedKFold(N_FOLDS, random_state=RANDOM_STATE)

#########################################################################################
# Dataset Preparation
#########################################################################################

all_ = None

# join only response (column -1) and therapy columns
dat = dataset[[dataset.columns[-1]]].join(therapy.dropna(), how='inner')

# transform categorical features into dummies
for column in dat:

    if dat[column].dtype == 'object':
        values = pd.get_dummies(dat[column])
        values.columns = [column + '_' + str(col) for col in values.columns]
    else:
        values = dat[column].fillna(0)

    all_ = values if all_ is None else pd.concat([all_, values], axis=1)

# join all data
all_ = all_.loc[all_.iloc[:,0].notna(),:]

all_ = all_.join(gene_fpkm, how='inner')[all_.columns]
gene_fpkm = all_.join(gene_fpkm, how='inner').iloc[:, len(all_.columns):]

# split independent and dependent variables
x, y = all_.values[:,1:], all_.values[:, 0]

# join treatments and dependent variable values to stratify fold based on these information
r = np.concatenate([x[:, 1:(therapy.shape[1] + 1)], y.reshape([-1,1])], axis=1)
r = np.apply_along_axis(lambda x: int(''.join([str(int(a)) for a in x])), axis=1, arr=r)

for fold, (train_index, valid_index) in enumerate(kfold.split(x, r)):
    
    y_train = all_.iloc[train_index, 0].values.ravel().reshape([-1, 1])
    y_valid = all_.iloc[valid_index,0].values.ravel().reshape([-1, 1])
    
    selected_genes = select_genes(gene_fpkm.iloc[train_index, :], y_train[:, 0], threshold=.005)[0]

    for ic, col in enumerate(dataset.columns[:-1]):
        
        print(col)
        
        #########################################################################################
        # Dataset Pre-processing
        #########################################################################################

        col_object = dataset[[col]] if dataset[col].dtype != 'object' else pd.get_dummies(dataset[col])
        
        x_train = all_.iloc[train_index, 1:].join(
            col_object, how='inner').join(gene_fpkm.iloc[train_index, :][selected_genes]).values
        x_valid = all_.iloc[valid_index, 1:].join(
            col_object, how='inner').join(gene_fpkm.iloc[valid_index, :][selected_genes]).values

        # format feature name
        col = col.lower().replace(' ', '').strip()

        lgb_train = lgb.Dataset(x_train, y_train)

        #########################################################################################
        # Baysian Optimization
        #########################################################################################

        file_name = 'output/brfl/optimization_lgbm_{}_{}_fold_{}.pkl'.format(
            fold, N_FOLDS, col)
        
        optimization_n_folds, optimization_n_calls = 2, 10
        
        opt = lightgbm_optimizer(x_train, y_train, 
                                 nfolds=optimization_n_folds, n_calls=optimization_n_calls, 
                                 random_state=RANDOM_STATE).x;

        params = {
            'learning_rate': opt[0],
            'num_leaves': opt[1],
            'max_depth': opt[2],
            'scale_pos_weight': opt[3],
            'min_child_weight': opt[4],
            'colsample_bytree': opt[5],
            'min_split_gain': opt[6],
            'min_child_samples': opt[7],
            'subsample': opt[8],
            'bin_construct_sample_cnt': opt[9],

            'objective':'binary',
            'metric':'auc',
            'is_unbalance':False,
            'nthread':24,          
            'verbose': -1,
            'device': 'gpu',
            'gpu_platform_id': 1,
            'gpu_device_id': 0,
            'random_state': RANDOM_STATE}

        #########################################################################################
        # Light GBM Train
        #########################################################################################
        
        model_name = 'output/brfl/classifier_{}_of_{}_fold_with_{}.lgbm'.format(
            fold, N_FOLDS, col)
        
        lgb_train = lgb.Dataset(x_train, y_train[:,0])
        lgb_valid = lgb.Dataset(x_valid, y_valid[:,0])

        gbm = lgb.train(params, lgb_train, valid_sets=lgb_valid, num_boost_round=100000, 
                        early_stopping_rounds=200, verbose_eval=False)
        
        with open(model_name, 'wb') as file:
            pickle.dump(gbm, file)
        
        #########################################################################################
        # Light GBM Inference
        #########################################################################################
        
        y_ = gbm.predict(x_valid)

        #########################################################################################
        # Performance Analysis
        #########################################################################################
        
        auc = roc_auc_score(y_valid, y_)

        t = optimize_threshold(y_train, gbm.predict(x_train))

        if t is None:
            t = np.mean(y_train)
        
        tn, fp, fn, tp = confusion_matrix(y_valid, [int(y >= t) for y in y_]).ravel()

        row = classification_metrics(tn, fp, fn, tp)
        
        row['auc'] = auc
        
        row['feature'] = col
        
        row['fold'] = fold + 1
        
        print(row)
        
        row = pd.Series(row).to_frame().T
        
        result = pd.DataFrame(row) if result is None else pd.concat([result, row], axis=0)
        
result
# Out:
# cmmc
# {'accuracy': 0.589041095890411, 'precision': 0.34285714285714286, 'sensitivity': 0.631578947368421, 'specificity': 0.5740740740740741, 'auc': 0.6500974658869395, 'feature': 'cmmc', 'fold': 1}
# ecog_ps
# {'accuracy': 0.6986301369863014, 'precision': 0.43478260869565216, 'sensitivity': 0.5263157894736842, 'specificity': 0.7592592592592593, 'auc': 0.6686159844054581, 'feature': 'ecog_ps', 'fold': 1}
# cell_markers
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': 'cell_markers', 'fold': 1}
# dna_index
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6491228070175439, 'feature': 'dna_index', 'fold': 1}
# lgh
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6354775828460039, 'feature': 'lgh', 'fold': 1}
# lgl
# {'accuracy': 0.6027397260273972, 'precision': 0.3611111111111111, 'sensitivity': 0.6842105263157895, 'specificity': 0.5740740740740741, 'auc': 0.635477582846004, 'feature': 'lgl', 'fold': 1}
# percent_aneuploid
# {'accuracy': 0.6438356164383562, 'precision': 0.3939393939393939, 'sensitivity': 0.6842105263157895, 'specificity': 0.6296296296296297, 'auc': 0.6637426900584795, 'feature': 'percent_aneuploid', 'fold': 1}
# percent_plama_cells_bone_marrow
# {'accuracy': 0.6301369863013698, 'precision': 0.38235294117647056, 'sensitivity': 0.6842105263157895, 'specificity': 0.6111111111111112, 'auc': 0.6773879142300194, 'feature': 'percent_plama_cells_bone_marrow', 'fold': 1}
# percent_plama_cells_peripherical_blood
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6491228070175439, 'feature': 'percent_plama_cells_peripherical_blood', 'fold': 1}
# creatinine
# {'accuracy': 0.5616438356164384, 'precision': 0.34146341463414637, 'sensitivity': 0.7368421052631579, 'specificity': 0.5, 'auc': 0.6725146198830408, 'feature': 'creatinine', 'fold': 1}
# iss
# {'accuracy': 0.5205479452054794, 'precision': 0.30952380952380953, 'sensitivity': 0.6842105263157895, 'specificity': 0.46296296296296297, 'auc': 0.6549707602339181, 'feature': 'iss', 'fold': 1}
# absolute_neutrophil
# {'accuracy': 0.5342465753424658, 'precision': 0.32558139534883723, 'sensitivity': 0.7368421052631579, 'specificity': 0.46296296296296297, 'auc': 0.6871345029239766, 'feature': 'absolute_neutrophil', 'fold': 1}
# platelet
# {'accuracy': 0.5342465753424658, 'precision': 0.32558139534883723, 'sensitivity': 0.7368421052631579, 'specificity': 0.46296296296296297, 'auc': 0.6500974658869395, 'feature': 'platelet', 'fold': 1}
# wbc_x10_10_9_l
# {'accuracy': 0.589041095890411, 'precision': 0.34285714285714286, 'sensitivity': 0.631578947368421, 'specificity': 0.5740740740740741, 'auc': 0.6627680311890838, 'feature': 'wbc_x10_10_9_l', 'fold': 1}
# bun
# {'accuracy': 0.6438356164383562, 'precision': 0.3939393939393939, 'sensitivity': 0.6842105263157895, 'specificity': 0.6296296296296297, 'auc': 0.6842105263157895, 'feature': 'bun', 'fold': 1}
# crp
# {'accuracy': 0.5753424657534246, 'precision': 0.35, 'sensitivity': 0.7368421052631579, 'specificity': 0.5185185185185185, 'auc': 0.6539961013645224, 'feature': 'crp', 'fold': 1}
# glucose
# {'accuracy': 0.6164383561643836, 'precision': 0.36363636363636365, 'sensitivity': 0.631578947368421, 'specificity': 0.6111111111111112, 'auc': 0.6705653021442496, 'feature': 'glucose', 'fold': 1}
# total_protein
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6491228070175439, 'feature': 'total_protein', 'fold': 1}
# albumin
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6491228070175439, 'feature': 'albumin', 'fold': 1}
# beta_2_microglobulin
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6549707602339181, 'feature': 'beta_2_microglobulin', 'fold': 1}
# calcium
# {'accuracy': 0.589041095890411, 'precision': 0.35135135135135137, 'sensitivity': 0.6842105263157895, 'specificity': 0.5555555555555556, 'auc': 0.6715399610136452, 'feature': 'calcium', 'fold': 1}
# hemoglobin
# {'accuracy': 0.589041095890411, 'precision': 0.34285714285714286, 'sensitivity': 0.631578947368421, 'specificity': 0.5740740740740741, 'auc': 0.6617933723196882, 'feature': 'hemoglobin', 'fold': 1}
# ldh
# {'accuracy': 0.5616438356164384, 'precision': 0.34146341463414637, 'sensitivity': 0.7368421052631579, 'specificity': 0.5, 'auc': 0.6773879142300195, 'feature': 'ldh', 'fold': 1}
# age
# {'accuracy': 0.6301369863013698, 'precision': 0.375, 'sensitivity': 0.631578947368421, 'specificity': 0.6296296296296297, 'auc': 0.6686159844054581, 'feature': 'age', 'fold': 1}
# family_cancer
# {'accuracy': 0.6986301369863014, 'precision': 0.43478260869565216, 'sensitivity': 0.5263157894736842, 'specificity': 0.7592592592592593, 'auc': 0.6686159844054581, 'feature': 'family_cancer', 'fold': 1}
# gender
# {'accuracy': 0.6027397260273972, 'precision': 0.3611111111111111, 'sensitivity': 0.6842105263157895, 'specificity': 0.5740740740740741, 'auc': 0.635477582846004, 'feature': 'gender', 'fold': 1}
# race
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': 'race', 'fold': 1}
# hyperdiploid_flag
# {'accuracy': 0.5753424657534246, 'precision': 0.3333333333333333, 'sensitivity': 0.631578947368421, 'specificity': 0.5555555555555556, 'auc': 0.6481481481481481, 'feature': 'hyperdiploid_flag', 'fold': 1}
# 13q14
# {'accuracy': 0.5753424657534246, 'precision': 0.3333333333333333, 'sensitivity': 0.631578947368421, 'specificity': 0.5555555555555556, 'auc': 0.6413255360623782, 'feature': '13q14', 'fold': 1}
# 13q34
# {'accuracy': 0.5616438356164384, 'precision': 0.32432432432432434, 'sensitivity': 0.631578947368421, 'specificity': 0.5370370370370371, 'auc': 0.635477582846004, 'feature': '13q34', 'fold': 1}
# 17p13
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': '17p13', 'fold': 1}
# 1q21
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': '1q21', 'fold': 1}
# 11p15
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': '11p15', 'fold': 1}
# 15q15
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': '15q15', 'fold': 1}
# 19q13
# {'accuracy': 0.589041095890411, 'precision': 0.3333333333333333, 'sensitivity': 0.5789473684210527, 'specificity': 0.5925925925925926, 'auc': 0.6481481481481481, 'feature': '19q13', 'fold': 1}
# 20q13
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6491228070175439, 'feature': '20q13', 'fold': 1}
# 21q22
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': '21q22', 'fold': 1}
# 3q21
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': '3q21', 'fold': 1}
# 5q31
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6578947368421052, 'feature': '5q31', 'fold': 1}
# 7q22
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': '7q22', 'fold': 1}
# 9q33
# {'accuracy': 0.6027397260273972, 'precision': 0.34375, 'sensitivity': 0.5789473684210527, 'specificity': 0.6111111111111112, 'auc': 0.6432748538011694, 'feature': '9q33', 'fold': 1}
# t_11_14_ccnd1
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': 't_11_14_ccnd1', 'fold': 1}
# t_12_14_ccnd2
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6491228070175439, 'feature': 't_12_14_ccnd2', 'fold': 1}
# t_14_16_maf
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6491228070175439, 'feature': 't_14_16_maf', 'fold': 1}
# t_14_20_mafb
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6491228070175439, 'feature': 't_14_20_mafb', 'fold': 1}
# t_4_14_whsc1
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': 't_4_14_whsc1', 'fold': 1}
# t_6_14_ccnd3
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6491228070175439, 'feature': 't_6_14_ccnd3', 'fold': 1}
# t_8_14_mafa
# {'accuracy': 0.726027397260274, 'precision': 0.4666666666666667, 'sensitivity': 0.3684210526315789, 'specificity': 0.8518518518518519, 'auc': 0.6491228070175439, 'feature': 't_8_14_mafa', 'fold': 1}
# t_8_14_myc
# {'accuracy': 0.6164383561643836, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5925925925925926, 'auc': 0.6364522417153996, 'feature': 't_8_14_myc', 'fold': 1}
# lga
# {'accuracy': 0.6986301369863014, 'precision': 0.43478260869565216, 'sensitivity': 0.5263157894736842, 'specificity': 0.7592592592592593, 'auc': 0.6617933723196882, 'feature': 'lga', 'fold': 1}
# lgg
# {'accuracy': 0.5753424657534246, 'precision': 0.34210526315789475, 'sensitivity': 0.6842105263157895, 'specificity': 0.5370370370370371, 'auc': 0.6695906432748538, 'feature': 'lgg', 'fold': 1}
# lgl_kappa
# {'accuracy': 0.6986301369863014, 'precision': 0.42857142857142855, 'sensitivity': 0.47368421052631576, 'specificity': 0.7777777777777778, 'auc': 0.665692007797271, 'feature': 'lgl_kappa', 'fold': 1}
# lgl_lambda
# {'accuracy': 0.6027397260273972, 'precision': 0.3611111111111111, 'sensitivity': 0.6842105263157895, 'specificity': 0.5740740740740741, 'auc': 0.6569200779727096, 'feature': 'lgl_lambda', 'fold': 1}
# lgm
# {'accuracy': 0.6438356164383562, 'precision': 0.3939393939393939, 'sensitivity': 0.6842105263157895, 'specificity': 0.6296296296296297, 'auc': 0.661793372319688, 'feature': 'lgm', 'fold': 1}
# m_protein
# {'accuracy': 0.6027397260273972, 'precision': 0.35294117647058826, 'sensitivity': 0.631578947368421, 'specificity': 0.5925925925925926, 'auc': 0.6598440545808967, 'feature': 'm_protein', 'fold': 1}
# first_line_transplant
# {'accuracy': 0.5753424657534246, 'precision': 0.3333333333333333, 'sensitivity': 0.631578947368421, 'specificity': 0.5555555555555556, 'auc': 0.6998050682261209, 'feature': 'first_line_transplant', 'fold': 1}
# cmmc
# {'accuracy': 0.6388888888888888, 'precision': 0.34782608695652173, 'sensitivity': 0.42105263157894735, 'specificity': 0.7169811320754716, 'auc': 0.625124131082423, 'feature': 'cmmc', 'fold': 2}
# ecog_ps
# {'accuracy': 0.7222222222222222, 'precision': 0.47368421052631576, 'sensitivity': 0.47368421052631576, 'specificity': 0.8113207547169812, 'auc': 0.708540218470705, 'feature': 'ecog_ps', 'fold': 2}
# cell_markers
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': 'cell_markers', 'fold': 2}
# dna_index
# {'accuracy': 0.6805555555555556, 'precision': 0.4090909090909091, 'sensitivity': 0.47368421052631576, 'specificity': 0.7547169811320755, 'auc': 0.6524329692154915, 'feature': 'dna_index', 'fold': 2}
# lgh
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': 'lgh', 'fold': 2}
# lgl
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': 'lgl', 'fold': 2}
# percent_aneuploid
# {'accuracy': 0.6805555555555556, 'precision': 0.4090909090909091, 'sensitivity': 0.47368421052631576, 'specificity': 0.7547169811320755, 'auc': 0.6524329692154915, 'feature': 'percent_aneuploid', 'fold': 2}
# percent_plama_cells_bone_marrow
# {'accuracy': 0.5972222222222222, 'precision': 0.34375, 'sensitivity': 0.5789473684210527, 'specificity': 0.6037735849056604, 'auc': 0.634558093346574, 'feature': 'percent_plama_cells_bone_marrow', 'fold': 2}
# percent_plama_cells_peripherical_blood
# {'accuracy': 0.6805555555555556, 'precision': 0.4090909090909091, 'sensitivity': 0.47368421052631576, 'specificity': 0.7547169811320755, 'auc': 0.6524329692154915, 'feature': 'percent_plama_cells_peripherical_blood', 'fold': 2}
# creatinine
# {'accuracy': 0.6388888888888888, 'precision': 0.34782608695652173, 'sensitivity': 0.42105263157894735, 'specificity': 0.7169811320754716, 'auc': 0.579940417080437, 'feature': 'creatinine', 'fold': 2}
# iss
# {'accuracy': 0.6805555555555556, 'precision': 0.4090909090909091, 'sensitivity': 0.47368421052631576, 'specificity': 0.7547169811320755, 'auc': 0.6524329692154915, 'feature': 'iss', 'fold': 2}
# absolute_neutrophil
# {'accuracy': 0.6805555555555556, 'precision': 0.375, 'sensitivity': 0.3157894736842105, 'specificity': 0.8113207547169812, 'auc': 0.6385302879841113, 'feature': 'absolute_neutrophil', 'fold': 2}
# platelet
# {'accuracy': 0.6111111111111112, 'precision': 0.36363636363636365, 'sensitivity': 0.631578947368421, 'specificity': 0.6037735849056604, 'auc': 0.6385302879841112, 'feature': 'platelet', 'fold': 2}
# wbc_x10_10_9_l
# {'accuracy': 0.5, 'precision': 0.3023255813953488, 'sensitivity': 0.6842105263157895, 'specificity': 0.4339622641509434, 'auc': 0.6405163853028798, 'feature': 'wbc_x10_10_9_l', 'fold': 2}
# bun
# {'accuracy': 0.625, 'precision': 0.375, 'sensitivity': 0.631578947368421, 'specificity': 0.6226415094339622, 'auc': 0.64746772591857, 'feature': 'bun', 'fold': 2}
# crp
# {'accuracy': 0.6805555555555556, 'precision': 0.35714285714285715, 'sensitivity': 0.2631578947368421, 'specificity': 0.8301886792452831, 'auc': 0.6434955312810328, 'feature': 'crp', 'fold': 2}
# glucose
# {'accuracy': 0.5138888888888888, 'precision': 0.2647058823529412, 'sensitivity': 0.47368421052631576, 'specificity': 0.5283018867924528, 'auc': 0.628599801390268, 'feature': 'glucose', 'fold': 2}
# total_protein
# {'accuracy': 0.5416666666666666, 'precision': 0.3055555555555556, 'sensitivity': 0.5789473684210527, 'specificity': 0.5283018867924528, 'auc': 0.631578947368421, 'feature': 'total_protein', 'fold': 2}
# albumin
# {'accuracy': 0.6388888888888888, 'precision': 0.34782608695652173, 'sensitivity': 0.42105263157894735, 'specificity': 0.7169811320754716, 'auc': 0.625124131082423, 'feature': 'albumin', 'fold': 2}
# beta_2_microglobulin
# {'accuracy': 0.6527777777777778, 'precision': 0.4, 'sensitivity': 0.631578947368421, 'specificity': 0.660377358490566, 'auc': 0.6623634558093346, 'feature': 'beta_2_microglobulin', 'fold': 2}
# calcium
# {'accuracy': 0.5833333333333334, 'precision': 0.3333333333333333, 'sensitivity': 0.5789473684210527, 'specificity': 0.5849056603773585, 'auc': 0.6534260178748759, 'feature': 'calcium', 'fold': 2}
# hemoglobin
# {'accuracy': 0.5416666666666666, 'precision': 0.325, 'sensitivity': 0.6842105263157895, 'specificity': 0.49056603773584906, 'auc': 0.6534260178748759, 'feature': 'hemoglobin', 'fold': 2}
# ldh
# {'accuracy': 0.7083333333333334, 'precision': 0.45454545454545453, 'sensitivity': 0.5263157894736842, 'specificity': 0.7735849056603774, 'auc': 0.6196623634558094, 'feature': 'ldh', 'fold': 2}
# age
# {'accuracy': 0.6388888888888888, 'precision': 0.34782608695652173, 'sensitivity': 0.42105263157894735, 'specificity': 0.7169811320754716, 'auc': 0.625124131082423, 'feature': 'age', 'fold': 2}
# family_cancer
# {'accuracy': 0.7222222222222222, 'precision': 0.47368421052631576, 'sensitivity': 0.47368421052631576, 'specificity': 0.8113207547169812, 'auc': 0.708540218470705, 'feature': 'family_cancer', 'fold': 2}
# gender
# {'accuracy': 0.5833333333333334, 'precision': 0.35135135135135137, 'sensitivity': 0.6842105263157895, 'specificity': 0.5471698113207547, 'auc': 0.6454816285998014, 'feature': 'gender', 'fold': 2}
# race
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': 'race', 'fold': 2}
# hyperdiploid_flag
# {'accuracy': 0.625, 'precision': 0.35714285714285715, 'sensitivity': 0.5263157894736842, 'specificity': 0.660377358490566, 'auc': 0.6097318768619662, 'feature': 'hyperdiploid_flag', 'fold': 2}
# 13q14
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': '13q14', 'fold': 2}
# 13q34
# {'accuracy': 0.5555555555555556, 'precision': 0.3142857142857143, 'sensitivity': 0.5789473684210527, 'specificity': 0.5471698113207547, 'auc': 0.6226415094339622, 'feature': '13q34', 'fold': 2}
# 17p13
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': '17p13', 'fold': 2}
# 1q21
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': '1q21', 'fold': 2}
# 11p15
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': '11p15', 'fold': 2}
# 15q15
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': '15q15', 'fold': 2}
# 19q13
# {'accuracy': 0.5277777777777778, 'precision': 0.3170731707317073, 'sensitivity': 0.6842105263157895, 'specificity': 0.4716981132075472, 'auc': 0.6127110228401191, 'feature': '19q13', 'fold': 2}
# 20q13
# {'accuracy': 0.6805555555555556, 'precision': 0.4090909090909091, 'sensitivity': 0.47368421052631576, 'specificity': 0.7547169811320755, 'auc': 0.6514399205561072, 'feature': '20q13', 'fold': 2}
# 21q22
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': '21q22', 'fold': 2}
# 3q21
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': '3q21', 'fold': 2}
# 5q31
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': '5q31', 'fold': 2}
# 7q22
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': '7q22', 'fold': 2}
# 9q33
# {'accuracy': 0.625, 'precision': 0.36666666666666664, 'sensitivity': 0.5789473684210527, 'specificity': 0.6415094339622641, 'auc': 0.6236345580933466, 'feature': '9q33', 'fold': 2}
# t_11_14_ccnd1
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': 't_11_14_ccnd1', 'fold': 2}
# t_12_14_ccnd2
# {'accuracy': 0.6805555555555556, 'precision': 0.4090909090909091, 'sensitivity': 0.47368421052631576, 'specificity': 0.7547169811320755, 'auc': 0.6514399205561072, 'feature': 't_12_14_ccnd2', 'fold': 2}
# t_14_16_maf
# {'accuracy': 0.6805555555555556, 'precision': 0.4090909090909091, 'sensitivity': 0.47368421052631576, 'specificity': 0.7547169811320755, 'auc': 0.6514399205561072, 'feature': 't_14_16_maf', 'fold': 2}
# t_14_20_mafb
# {'accuracy': 0.6805555555555556, 'precision': 0.4090909090909091, 'sensitivity': 0.47368421052631576, 'specificity': 0.7547169811320755, 'auc': 0.6524329692154915, 'feature': 't_14_20_mafb', 'fold': 2}
# t_4_14_whsc1
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': 't_4_14_whsc1', 'fold': 2}
# t_6_14_ccnd3
# {'accuracy': 0.6805555555555556, 'precision': 0.4090909090909091, 'sensitivity': 0.47368421052631576, 'specificity': 0.7547169811320755, 'auc': 0.6524329692154915, 'feature': 't_6_14_ccnd3', 'fold': 2}
# t_8_14_mafa
# {'accuracy': 0.6805555555555556, 'precision': 0.4090909090909091, 'sensitivity': 0.47368421052631576, 'specificity': 0.7547169811320755, 'auc': 0.6514399205561072, 'feature': 't_8_14_mafa', 'fold': 2}
# t_8_14_myc
# {'accuracy': 0.6111111111111112, 'precision': 0.3448275862068966, 'sensitivity': 0.5263157894736842, 'specificity': 0.6415094339622641, 'auc': 0.6107249255213505, 'feature': 't_8_14_myc', 'fold': 2}
# lga
# {'accuracy': 0.6805555555555556, 'precision': 0.4166666666666667, 'sensitivity': 0.5263157894736842, 'specificity': 0.7358490566037735, 'auc': 0.6454816285998014, 'feature': 'lga', 'fold': 2}
# lgg
# {'accuracy': 0.6666666666666666, 'precision': 0.391304347826087, 'sensitivity': 0.47368421052631576, 'specificity': 0.7358490566037735, 'auc': 0.6514399205561072, 'feature': 'lgg', 'fold': 2}
# lgl_kappa
# {'accuracy': 0.625, 'precision': 0.36666666666666664, 'sensitivity': 0.5789473684210527, 'specificity': 0.6415094339622641, 'auc': 0.64746772591857, 'feature': 'lgl_kappa', 'fold': 2}
# lgl_lambda
# {'accuracy': 0.5694444444444444, 'precision': 0.35, 'sensitivity': 0.7368421052631579, 'specificity': 0.5094339622641509, 'auc': 0.6295928500496524, 'feature': 'lgl_lambda', 'fold': 2}
# lgm
# {'accuracy': 0.6111111111111112, 'precision': 0.37142857142857144, 'sensitivity': 0.6842105263157895, 'specificity': 0.5849056603773585, 'auc': 0.6573982125124131, 'feature': 'lgm', 'fold': 2}
# m_protein
# {'accuracy': 0.5555555555555556, 'precision': 0.34146341463414637, 'sensitivity': 0.7368421052631579, 'specificity': 0.49056603773584906, 'auc': 0.6365441906653426, 'feature': 'm_protein', 'fold': 2}
# first_line_transplant
# {'accuracy': 0.625, 'precision': 0.36666666666666664, 'sensitivity': 0.5789473684210527, 'specificity': 0.6415094339622641, 'auc': 0.6335650446871897, 'feature': 'first_line_transplant', 'fold': 2}
# cmmc
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'cmmc', 'fold': 3}
# ecog_ps
# {'accuracy': 0.6338028169014085, 'precision': 0.25, 'sensitivity': 0.2222222222222222, 'specificity': 0.7735849056603774, 'auc': 0.5230607966457024, 'feature': 'ecog_ps', 'fold': 3}
# cell_markers
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': 'cell_markers', 'fold': 3}
# dna_index
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'dna_index', 'fold': 3}
# lgh
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': 'lgh', 'fold': 3}
# lgl
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': 'lgl', 'fold': 3}
# percent_aneuploid
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'percent_aneuploid', 'fold': 3}
# percent_plama_cells_bone_marrow
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'percent_plama_cells_bone_marrow', 'fold': 3}
# percent_plama_cells_peripherical_blood
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'percent_plama_cells_peripherical_blood', 'fold': 3}
# creatinine
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'creatinine', 'fold': 3}
# iss
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'iss', 'fold': 3}
# absolute_neutrophil
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'absolute_neutrophil', 'fold': 3}
# platelet
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'platelet', 'fold': 3}
# wbc_x10_10_9_l
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'wbc_x10_10_9_l', 'fold': 3}
# bun
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'bun', 'fold': 3}
# crp
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'crp', 'fold': 3}
# glucose
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'glucose', 'fold': 3}
# total_protein
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'total_protein', 'fold': 3}
# albumin
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'albumin', 'fold': 3}
# beta_2_microglobulin
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5639412997903563, 'feature': 'beta_2_microglobulin', 'fold': 3}
# calcium
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'calcium', 'fold': 3}
# hemoglobin
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'hemoglobin', 'fold': 3}
# ldh
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'ldh', 'fold': 3}
# age
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'age', 'fold': 3}
# family_cancer
# {'accuracy': 0.6338028169014085, 'precision': 0.25, 'sensitivity': 0.2222222222222222, 'specificity': 0.7735849056603774, 'auc': 0.5230607966457024, 'feature': 'family_cancer', 'fold': 3}
# gender
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': 'gender', 'fold': 3}
# race
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': 'race', 'fold': 3}
# hyperdiploid_flag
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': 'hyperdiploid_flag', 'fold': 3}
# 13q14
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '13q14', 'fold': 3}
# 13q34
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '13q34', 'fold': 3}
# 17p13
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '17p13', 'fold': 3}
# 1q21
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '1q21', 'fold': 3}
# 11p15
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '11p15', 'fold': 3}
# 15q15
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '15q15', 'fold': 3}
# 19q13
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '19q13', 'fold': 3}
# 20q13
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': '20q13', 'fold': 3}
# 21q22
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '21q22', 'fold': 3}
# 3q21
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '3q21', 'fold': 3}
# 5q31
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '5q31', 'fold': 3}
# 7q22
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '7q22', 'fold': 3}
# 9q33
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': '9q33', 'fold': 3}
# t_11_14_ccnd1
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': 't_11_14_ccnd1', 'fold': 3}
# t_12_14_ccnd2
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 't_12_14_ccnd2', 'fold': 3}
# t_14_16_maf
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 't_14_16_maf', 'fold': 3}
# t_14_20_mafb
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 't_14_20_mafb', 'fold': 3}
# t_4_14_whsc1
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': 't_4_14_whsc1', 'fold': 3}
# t_6_14_ccnd3
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 't_6_14_ccnd3', 'fold': 3}
# t_8_14_mafa
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 't_8_14_mafa', 'fold': 3}
# t_8_14_myc
# {'accuracy': 0.5915492957746479, 'precision': 0.23809523809523808, 'sensitivity': 0.2777777777777778, 'specificity': 0.6981132075471698, 'auc': 0.5628930817610063, 'feature': 't_8_14_myc', 'fold': 3}
# lga
# {'accuracy': 0.6901408450704225, 'precision': 0.3333333333333333, 'sensitivity': 0.2222222222222222, 'specificity': 0.8490566037735849, 'auc': 0.5723270440251572, 'feature': 'lga', 'fold': 3}
# lgg
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'lgg', 'fold': 3}
# lgl_kappa
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'lgl_kappa', 'fold': 3}
# lgl_lambda
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'lgl_lambda', 'fold': 3}
# lgm
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'lgm', 'fold': 3}
# m_protein
# {'accuracy': 0.6056338028169014, 'precision': 0.3076923076923077, 'sensitivity': 0.4444444444444444, 'specificity': 0.660377358490566, 'auc': 0.5628930817610063, 'feature': 'm_protein', 'fold': 3}
# first_line_transplant
# {'accuracy': 0.49295774647887325, 'precision': 0.23529411764705882, 'sensitivity': 0.4444444444444444, 'specificity': 0.5094339622641509, 'auc': 0.549266247379455, 'feature': 'first_line_transplant', 'fold': 3}
# cmmc
# {'accuracy': 0.4492753623188406, 'precision': 0.2765957446808511, 'sensitivity': 0.7647058823529411, 'specificity': 0.34615384615384615, 'auc': 0.5995475113122172, 'feature': 'cmmc', 'fold': 4}
# ecog_ps
# {'accuracy': 0.6811594202898551, 'precision': 0.38095238095238093, 'sensitivity': 0.47058823529411764, 'specificity': 0.75, 'auc': 0.581447963800905, 'feature': 'ecog_ps', 'fold': 4}
# cell_markers
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.572398190045249, 'feature': 'cell_markers', 'fold': 4}
# dna_index
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6040723981900453, 'feature': 'dna_index', 'fold': 4}
# lgh
# {'accuracy': 0.5507246376811594, 'precision': 0.3055555555555556, 'sensitivity': 0.6470588235294118, 'specificity': 0.5192307692307693, 'auc': 0.5701357466063348, 'feature': 'lgh', 'fold': 4}
# lgl
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.572398190045249, 'feature': 'lgl', 'fold': 4}
# percent_aneuploid
# {'accuracy': 0.6376811594202898, 'precision': 0.3181818181818182, 'sensitivity': 0.4117647058823529, 'specificity': 0.7115384615384616, 'auc': 0.578054298642534, 'feature': 'percent_aneuploid', 'fold': 4}
# percent_plama_cells_bone_marrow
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.6063348416289593, 'feature': 'percent_plama_cells_bone_marrow', 'fold': 4}
# percent_plama_cells_peripherical_blood
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6040723981900453, 'feature': 'percent_plama_cells_peripherical_blood', 'fold': 4}
# creatinine
# {'accuracy': 0.5942028985507246, 'precision': 0.3333333333333333, 'sensitivity': 0.6470588235294118, 'specificity': 0.5769230769230769, 'auc': 0.5916289592760181, 'feature': 'creatinine', 'fold': 4}
# iss
# {'accuracy': 0.5217391304347826, 'precision': 0.3, 'sensitivity': 0.7058823529411765, 'specificity': 0.46153846153846156, 'auc': 0.6119909502262444, 'feature': 'iss', 'fold': 4}
# absolute_neutrophil
# {'accuracy': 0.6666666666666666, 'precision': 0.36363636363636365, 'sensitivity': 0.47058823529411764, 'specificity': 0.7307692307692307, 'auc': 0.5791855203619909, 'feature': 'absolute_neutrophil', 'fold': 4}
# platelet
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6029411764705882, 'feature': 'platelet', 'fold': 4}
# wbc_x10_10_9_l
# {'accuracy': 0.6086956521739131, 'precision': 0.34375, 'sensitivity': 0.6470588235294118, 'specificity': 0.5961538461538461, 'auc': 0.5961538461538461, 'feature': 'wbc_x10_10_9_l', 'fold': 4}
# bun
# {'accuracy': 0.6376811594202898, 'precision': 0.3181818181818182, 'sensitivity': 0.4117647058823529, 'specificity': 0.7115384615384616, 'auc': 0.5916289592760181, 'feature': 'bun', 'fold': 4}
# crp
# {'accuracy': 0.5797101449275363, 'precision': 0.2692307692307692, 'sensitivity': 0.4117647058823529, 'specificity': 0.6346153846153846, 'auc': 0.590497737556561, 'feature': 'crp', 'fold': 4}
# glucose
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6040723981900453, 'feature': 'glucose', 'fold': 4}
# total_protein
# {'accuracy': 0.6376811594202898, 'precision': 0.3181818181818182, 'sensitivity': 0.4117647058823529, 'specificity': 0.7115384615384616, 'auc': 0.6097285067873304, 'feature': 'total_protein', 'fold': 4}
# albumin
# {'accuracy': 0.6811594202898551, 'precision': 0.38095238095238093, 'sensitivity': 0.47058823529411764, 'specificity': 0.75, 'auc': 0.5848416289592759, 'feature': 'albumin', 'fold': 4}
# beta_2_microglobulin
# {'accuracy': 0.6231884057971014, 'precision': 0.2857142857142857, 'sensitivity': 0.35294117647058826, 'specificity': 0.7115384615384616, 'auc': 0.6131221719457014, 'feature': 'beta_2_microglobulin', 'fold': 4}
# calcium
# {'accuracy': 0.6086956521739131, 'precision': 0.35294117647058826, 'sensitivity': 0.7058823529411765, 'specificity': 0.5769230769230769, 'auc': 0.583710407239819, 'feature': 'calcium', 'fold': 4}
# hemoglobin
# {'accuracy': 0.5652173913043478, 'precision': 0.3142857142857143, 'sensitivity': 0.6470588235294118, 'specificity': 0.5384615384615384, 'auc': 0.6097285067873304, 'feature': 'hemoglobin', 'fold': 4}
# ldh
# {'accuracy': 0.6811594202898551, 'precision': 0.3684210526315789, 'sensitivity': 0.4117647058823529, 'specificity': 0.7692307692307693, 'auc': 0.6040723981900452, 'feature': 'ldh', 'fold': 4}
# age
# {'accuracy': 0.6086956521739131, 'precision': 0.34375, 'sensitivity': 0.6470588235294118, 'specificity': 0.5961538461538461, 'auc': 0.5791855203619909, 'feature': 'age', 'fold': 4}
# family_cancer
# {'accuracy': 0.5652173913043478, 'precision': 0.32432432432432434, 'sensitivity': 0.7058823529411765, 'specificity': 0.5192307692307693, 'auc': 0.5916289592760181, 'feature': 'family_cancer', 'fold': 4}
# gender
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': 'gender', 'fold': 4}
# race
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': 'race', 'fold': 4}
# hyperdiploid_flag
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': 'hyperdiploid_flag', 'fold': 4}
# 13q14
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': '13q14', 'fold': 4}
# 13q34
# {'accuracy': 0.5507246376811594, 'precision': 0.3055555555555556, 'sensitivity': 0.6470588235294118, 'specificity': 0.5192307692307693, 'auc': 0.5701357466063348, 'feature': '13q34', 'fold': 4}
# 17p13
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': '17p13', 'fold': 4}
# 1q21
# {'accuracy': 0.5507246376811594, 'precision': 0.3055555555555556, 'sensitivity': 0.6470588235294118, 'specificity': 0.5192307692307693, 'auc': 0.5701357466063348, 'feature': '1q21', 'fold': 4}
# 11p15
# {'accuracy': 0.5507246376811594, 'precision': 0.3055555555555556, 'sensitivity': 0.6470588235294118, 'specificity': 0.5192307692307693, 'auc': 0.5701357466063348, 'feature': '11p15', 'fold': 4}
# 15q15
# {'accuracy': 0.5507246376811594, 'precision': 0.3055555555555556, 'sensitivity': 0.6470588235294118, 'specificity': 0.5192307692307693, 'auc': 0.5701357466063348, 'feature': '15q15', 'fold': 4}
# 19q13
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': '19q13', 'fold': 4}
# 20q13
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6006787330316742, 'feature': '20q13', 'fold': 4}
# 21q22
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': '21q22', 'fold': 4}
# 3q21
# {'accuracy': 0.5507246376811594, 'precision': 0.3055555555555556, 'sensitivity': 0.6470588235294118, 'specificity': 0.5192307692307693, 'auc': 0.5701357466063348, 'feature': '3q21', 'fold': 4}
# 5q31
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': '5q31', 'fold': 4}
# 7q22
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': '7q22', 'fold': 4}
# 9q33
# {'accuracy': 0.5507246376811594, 'precision': 0.29411764705882354, 'sensitivity': 0.5882352941176471, 'specificity': 0.5384615384615384, 'auc': 0.5701357466063348, 'feature': '9q33', 'fold': 4}
# t_11_14_ccnd1
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': 't_11_14_ccnd1', 'fold': 4}
# t_12_14_ccnd2
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6018099547511312, 'feature': 't_12_14_ccnd2', 'fold': 4}
# t_14_16_maf
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6029411764705882, 'feature': 't_14_16_maf', 'fold': 4}
# t_14_20_mafb
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6018099547511312, 'feature': 't_14_20_mafb', 'fold': 4}
# t_4_14_whsc1
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': 't_4_14_whsc1', 'fold': 4}
# t_6_14_ccnd3
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6018099547511312, 'feature': 't_6_14_ccnd3', 'fold': 4}
# t_8_14_mafa
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6018099547511312, 'feature': 't_8_14_mafa', 'fold': 4}
# t_8_14_myc
# {'accuracy': 0.43478260869565216, 'precision': 0.2608695652173913, 'sensitivity': 0.7058823529411765, 'specificity': 0.34615384615384615, 'auc': 0.5712669683257919, 'feature': 't_8_14_myc', 'fold': 4}
# lga
# {'accuracy': 0.6376811594202898, 'precision': 0.36666666666666664, 'sensitivity': 0.6470588235294118, 'specificity': 0.6346153846153846, 'auc': 0.5938914027149321, 'feature': 'lga', 'fold': 4}
# lgg
# {'accuracy': 0.6521739130434783, 'precision': 0.3793103448275862, 'sensitivity': 0.6470588235294118, 'specificity': 0.6538461538461539, 'auc': 0.5972850678733032, 'feature': 'lgg', 'fold': 4}
# lgl_kappa
# {'accuracy': 0.5797101449275363, 'precision': 0.3125, 'sensitivity': 0.5882352941176471, 'specificity': 0.5769230769230769, 'auc': 0.6040723981900453, 'feature': 'lgl_kappa', 'fold': 4}
# lgl_lambda
# {'accuracy': 0.6666666666666666, 'precision': 0.35, 'sensitivity': 0.4117647058823529, 'specificity': 0.75, 'auc': 0.6278280542986425, 'feature': 'lgl_lambda', 'fold': 4}
# lgm
# {'accuracy': 0.6521739130434783, 'precision': 0.36, 'sensitivity': 0.5294117647058824, 'specificity': 0.6923076923076923, 'auc': 0.5882352941176471, 'feature': 'lgm', 'fold': 4}
# m_protein
# {'accuracy': 0.6521739130434783, 'precision': 0.3333333333333333, 'sensitivity': 0.4117647058823529, 'specificity': 0.7307692307692307, 'auc': 0.5950226244343891, 'feature': 'm_protein', 'fold': 4}
# first_line_transplant
# {'accuracy': 0.5797101449275363, 'precision': 0.2692307692307692, 'sensitivity': 0.4117647058823529, 'specificity': 0.6346153846153846, 'auc': 0.5791855203619909, 'feature': 'first_line_transplant', 'fold': 4}
# cmmc
# {'accuracy': 0.6956521739130435, 'precision': 0.4166666666666667, 'sensitivity': 0.5882352941176471, 'specificity': 0.7307692307692307, 'auc': 0.6889140271493213, 'feature': 'cmmc', 'fold': 5}
# ecog_ps
# {'accuracy': 0.6666666666666666, 'precision': 0.3125, 'sensitivity': 0.29411764705882354, 'specificity': 0.7884615384615384, 'auc': 0.6764705882352942, 'feature': 'ecog_ps', 'fold': 5}
# cell_markers
# {'accuracy': 0.6521739130434783, 'precision': 0.26666666666666666, 'sensitivity': 0.23529411764705882, 'specificity': 0.7884615384615384, 'auc': 0.6538461538461539, 'feature': 'cell_markers', 'fold': 5}
# dna_index
# {'accuracy': 0.6956521739130435, 'precision': 0.4166666666666667, 'sensitivity': 0.5882352941176471, 'specificity': 0.7307692307692307, 'auc': 0.6889140271493213, 'feature': 'dna_index', 'fold': 5}
# lgh
# {'accuracy': 0.6521739130434783, 'precision': 0.26666666666666666, 'sensitivity': 0.23529411764705882, 'specificity': 0.7884615384615384, 'auc': 0.6538461538461539, 'feature': 'lgh', 'fold': 5}
# lgl
# {'accuracy': 0.6521739130434783, 'precision': 0.26666666666666666, 'sensitivity': 0.23529411764705882, 'specificity': 0.7884615384615384, 'auc': 0.6538461538461539, 'feature': 'lgl', 'fold': 5}
# percent_aneuploid
# {'accuracy': 0.6956521739130435, 'precision': 0.4166666666666667, 'sensitivity': 0.5882352941176471, 'specificity': 0.7307692307692307, 'auc': 0.6889140271493213, 'feature': 'percent_aneuploid', 'fold': 5}
# percent_plama_cells_bone_marrow
# {'accuracy': 0.6956521739130435, 'precision': 0.4166666666666667, 'sensitivity': 0.5882352941176471, 'specificity': 0.7307692307692307, 'auc': 0.6889140271493213, 'feature': 'percent_plama_cells_bone_marrow', 'fold': 5}
# percent_plama_cells_peripherical_blood
# ...
# platelet
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'platelet', 'fold': 10}
# wbc_x10_10_9_l
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'wbc_x10_10_9_l', 'fold': 10}
# bun
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'bun', 'fold': 10}
# crp
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'crp', 'fold': 10}
# glucose
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'glucose', 'fold': 10}
# total_protein
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'total_protein', 'fold': 10}
# albumin
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'albumin', 'fold': 10}
# beta_2_microglobulin
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.4693877551020409, 'feature': 'beta_2_microglobulin', 'fold': 10}
# calcium
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'calcium', 'fold': 10}
# hemoglobin
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'hemoglobin', 'fold': 10}
# ldh
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'ldh', 'fold': 10}
# age
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'age', 'fold': 10}
# family_cancer
# {'accuracy': 0.42857142857142855, 'precision': 0.21052631578947367, 'sensitivity': 0.5714285714285714, 'specificity': 0.3877551020408163, 'auc': 0.3906705539358601, 'feature': 'family_cancer', 'fold': 10}
# gender
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': 'gender', 'fold': 10}
# race
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': 'race', 'fold': 10}
# hyperdiploid_flag
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': 'hyperdiploid_flag', 'fold': 10}
# 13q14
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '13q14', 'fold': 10}
# 13q34
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '13q34', 'fold': 10}
# 17p13
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '17p13', 'fold': 10}
# 1q21
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '1q21', 'fold': 10}
# 11p15
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '11p15', 'fold': 10}
# 15q15
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '15q15', 'fold': 10}
# 19q13
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '19q13', 'fold': 10}
# 20q13
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': '20q13', 'fold': 10}
# 21q22
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '21q22', 'fold': 10}
# 3q21
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '3q21', 'fold': 10}
# 5q31
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '5q31', 'fold': 10}
# 7q22
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '7q22', 'fold': 10}
# 9q33
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': '9q33', 'fold': 10}
# t_11_14_ccnd1
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': 't_11_14_ccnd1', 'fold': 10}
# t_12_14_ccnd2
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 't_12_14_ccnd2', 'fold': 10}
# t_14_16_maf
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 't_14_16_maf', 'fold': 10}
# t_14_20_mafb
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 't_14_20_mafb', 'fold': 10}
# t_4_14_whsc1
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': 't_4_14_whsc1', 'fold': 10}
# t_6_14_ccnd3
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 't_6_14_ccnd3', 'fold': 10}
# t_8_14_mafa
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 't_8_14_mafa', 'fold': 10}
# t_8_14_myc
# {'accuracy': 0.49206349206349204, 'precision': 0.2, 'sensitivity': 0.42857142857142855, 'specificity': 0.5102040816326531, 'auc': 0.43002915451895046, 'feature': 't_8_14_myc', 'fold': 10}
# lga
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'lga', 'fold': 10}
# lgg
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'lgg', 'fold': 10}
# lgl_kappa
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'lgl_kappa', 'fold': 10}
# lgl_lambda
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'lgl_lambda', 'fold': 10}
# lgm
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'lgm', 'fold': 10}
# m_protein
# {'accuracy': 0.6031746031746031, 'precision': 0.13333333333333333, 'sensitivity': 0.14285714285714285, 'specificity': 0.7346938775510204, 'auc': 0.45335276967930027, 'feature': 'm_protein', 'fold': 10}
# first_line_transplant
# {'accuracy': 0.6031746031746031, 'precision': 0.2608695652173913, 'sensitivity': 0.42857142857142855, 'specificity': 0.6530612244897959, 'auc': 0.4620991253644315, 'feature': 'first_line_transplant', 'fold': 10}
#     accuracy precision sensitivity specificity       auc  \
# 0   0.589041  0.342857    0.631579    0.574074  0.650097
# 0    0.69863  0.434783    0.526316    0.759259  0.668616
# 0   0.616438  0.371429    0.684211    0.592593  0.636452
# 0   0.726027  0.466667    0.368421    0.851852  0.649123
# 0   0.616438  0.371429    0.684211    0.592593  0.635478
# 0    0.60274  0.361111    0.684211    0.574074  0.635478
# 0   0.643836  0.393939    0.684211     0.62963  0.663743
# 0   0.630137  0.382353    0.684211    0.611111  0.677388
# 0   0.726027  0.466667    0.368421    0.851852  0.649123
# 0   0.561644  0.341463    0.736842         0.5  0.672515
# 0   0.520548  0.309524    0.684211    0.462963  0.654971
# 0   0.534247  0.325581    0.736842    0.462963  0.687135
# 0   0.534247  0.325581    0.736842    0.462963  0.650097
# 0   0.589041  0.342857    0.631579    0.574074  0.662768
# 0   0.643836  0.393939    0.684211     0.62963  0.684211
# 0   0.575342      0.35    0.736842    0.518519  0.653996
# 0   0.616438  0.363636    0.631579    0.611111  0.670565
# 0   0.726027  0.466667    0.368421    0.851852  0.649123
# 0   0.726027  0.466667    0.368421    0.851852  0.649123
# 0   0.726027  0.466667    0.368421    0.851852  0.654971
# 0   0.589041  0.351351    0.684211    0.555556   0.67154
# 0   0.589041  0.342857    0.631579    0.574074  0.661793
# 0   0.561644  0.341463    0.736842         0.5  0.677388
# 0   0.630137     0.375    0.631579     0.62963  0.668616
# 0    0.69863  0.434783    0.526316    0.759259  0.668616
# 0    0.60274  0.361111    0.684211    0.574074  0.635478
# 0   0.616438  0.371429    0.684211    0.592593  0.636452
# 0   0.575342  0.333333    0.631579    0.555556  0.648148
# 0   0.575342  0.333333    0.631579    0.555556  0.641326
# 0   0.561644  0.324324    0.631579    0.537037  0.635478
# ..       ...       ...         ...         ...       ...
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.492063       0.2    0.428571    0.510204  0.430029
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.603175  0.133333    0.142857    0.734694  0.453353
# 0   0.603175   0.26087    0.428571    0.653061  0.462099
#
#                                    feature fold
# 0                                     cmmc    1
# 0                                  ecog_ps    1
# 0                             cell_markers    1
# 0                                dna_index    1
# 0                                      lgh    1
# 0                                      lgl    1
# 0                        percent_aneuploid    1
# 0          percent_plama_cells_bone_marrow    1
# 0   percent_plama_cells_peripherical_blood    1
# 0                               creatinine    1
# 0                                      iss    1
# 0                      absolute_neutrophil    1
# 0                                 platelet    1
# 0                           wbc_x10_10_9_l    1
# 0                                      bun    1
# 0                                      crp    1
# 0                                  glucose    1
# 0                            total_protein    1
# 0                                  albumin    1
# 0                     beta_2_microglobulin    1
# 0                                  calcium    1
# 0                               hemoglobin    1
# 0                                      ldh    1
# 0                                      age    1
# 0                            family_cancer    1
# 0                                   gender    1
# 0                                     race    1
# 0                        hyperdiploid_flag    1
# 0                                    13q14    1
# 0                                    13q34    1
# ..                                     ...  ...
# 0                                     race   10
# 0                        hyperdiploid_flag   10
# 0                                    13q14   10
# 0                                    13q34   10
# 0                                    17p13   10
# 0                                     1q21   10
# 0                                    11p15   10
# 0                                    15q15   10
# 0                                    19q13   10
# 0                                    20q13   10
# 0                                    21q22   10
# 0                                     3q21   10
# 0                                     5q31   10
# 0                                     7q22   10
# 0                                     9q33   10
# 0                            t_11_14_ccnd1   10
# 0                            t_12_14_ccnd2   10
# 0                              t_14_16_maf   10
# 0                             t_14_20_mafb   10
# 0                             t_4_14_whsc1   10
# 0                             t_6_14_ccnd3   10
# 0                              t_8_14_mafa   10
# 0                               t_8_14_myc   10
# 0                                      lga   10
# 0                                      lgg   10
# 0                                lgl_kappa   10
# 0                               lgl_lambda   10
# 0                                      lgm   10
# 0                                m_protein   10
# 0                    first_line_transplant   10
#
# [560 rows x 7 columns]

# %%
for c in result.columns:
    if c != 'feature':
        result[c] = result[c].astype(float)

fish = ['11p15', '13q14', '13q34', '15q15', '17p13', '19q13', '1q21', '20q13',
        '21q22', '3q21', '5q31', '7q22', '9q33', 't_11_14_ccnd1', 't_12_14_ccnd2', 't_14_16_maf', 't_14_20_mafb',
        't_4_14_whsc1', 't_6_14_ccnd3', 't_8_14_mafa', 't_8_14_myc', 'hyperdiploid_flag']

result[~result['feature'].isin(fish)].to_csv('output/brfl/clinical_and_gene_markers.csv', sep=',', index=False)

result.groupby('feature').mean().drop(fish).drop(columns='fold')
# Out:
#                                         accuracy  precision  sensitivity  \
# feature
# absolute_neutrophil                     0.598887   0.332384     0.534161
# age                                     0.627543   0.313260     0.503069
# albumin                                 0.652508   0.340960     0.428434
# beta_2_microglobulin                    0.582437   0.316347     0.539823
# bun                                     0.623946   0.310889     0.498712
# calcium                                 0.630695   0.329611     0.506475
# cell_markers                            0.615600   0.302934     0.433704
# cmmc                                    0.610050   0.307306     0.514834
# creatinine                              0.605635   0.303036     0.525360
# crp                                     0.601706   0.286762     0.464613
# dna_index                               0.629138   0.320878     0.482016
# ecog_ps                                 0.633899   0.336182     0.432306
# family_cancer                           0.622304   0.308974     0.443651
# first_line_transplant                   0.631881   0.328848     0.489447
# gender                                  0.600085   0.272546     0.436048
# glucose                                 0.580793   0.304248     0.557492
# hemoglobin                              0.630559   0.342681     0.519721
# iss                                     0.611059   0.304137     0.486284
# ldh                                     0.584115   0.306675     0.525802
# lga                                     0.650248   0.326177     0.464040
# lgg                                     0.638881   0.335216     0.490066
# lgh                                     0.608014   0.286135     0.450091
# lgl                                     0.595050   0.280635     0.455973
# lgl_kappa                               0.642922   0.334974     0.466514
# lgl_lambda                              0.642836   0.321656     0.468903
# lgm                                     0.654237   0.345108     0.485068
# m_protein                               0.649147   0.345321     0.486329
# percent_aneuploid                       0.641435   0.323636     0.471158
# percent_plama_cells_bone_marrow         0.623942   0.317619     0.496811
# percent_plama_cells_peripherical_blood  0.629478   0.320865     0.482016
# platelet                                0.614270   0.316467     0.517001
# race                                    0.596420   0.281666     0.455973
# total_protein                           0.640906   0.320425     0.447585
# wbc_x10_10_9_l                          0.620686   0.319504     0.475183
#
#                                         specificity       auc
# feature
# absolute_neutrophil                        0.622705  0.619441
# age                                        0.667014  0.618195
# albumin                                    0.725467  0.613412
# beta_2_microglobulin                       0.600973  0.624502
# bun                                        0.662965  0.625662
# calcium                                    0.669322  0.622514
# cell_markers                               0.671780  0.597340
# cmmc                                       0.640074  0.619076
# creatinine                                 0.630590  0.618752
# crp                                        0.644455  0.605362
# dna_index                                  0.677241  0.620424
# ecog_ps                                    0.701409  0.595036
# family_cancer                              0.679577  0.601282
# first_line_transplant                      0.675418  0.615349
# gender                                     0.647648  0.600427
# glucose                                    0.585295  0.613734
# hemoglobin                                 0.662740  0.631172
# iss                                        0.648891  0.622699
# ldh                                        0.605327  0.615278
# lga                                        0.708963  0.620641
# lgg                                        0.686257  0.620650
# lgh                                        0.656242  0.597410
# lgl                                        0.637082  0.598207
# lgl_kappa                                  0.699205  0.619512
# lgl_lambda                                 0.695166  0.621485
# lgm                                        0.706268  0.620960
# m_protein                                  0.698977  0.621728
# percent_aneuploid                          0.695634  0.622664
# percent_plama_cells_bone_marrow            0.662149  0.620671
# percent_plama_cells_peripherical_blood     0.677472  0.619917
# platelet                                   0.644181  0.620982
# race                                       0.638934  0.597906
# total_protein                              0.701676  0.617427
# wbc_x10_10_9_l                             0.665618  0.622858
